# %% [markdown]
# # Summarising results
#
# This notebook summarises results into a Pandas dataframe which is then
# reformatted into a table suitable for publishing.

# %%
import json
from collections import defaultdict
from collections.abc import Mapping
from datetime import datetime, timezone
from itertools import product
from pathlib import Path
from typing import Any, Literal, TypeAlias, cast
from collections.abc import Iterable

import pandas as pd
from pandas.io.formats.style import Styler

import qaoa_parameter_setting.utils as utils
from qaoa_parameter_setting.utils.database import ResultsDatabase
from qaoa_parameter_setting.utils.database.summary_table_formatter import (
    convert_evaluation_to_multicolumn_latex,
    formatted_styler_for,
)
from qaoa_parameter_setting.utils.types import (
    Depth,
    EvaluationType,
    GraphKey,
    GraphType,
    MethodConfigJSON,
)
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython

# %%
# Make sure to change this when regenerating all tables.
PROBLEM_CLASS: Literal["MC", "MIS"] = "MC"

# %%
# TABLE_JSON: str | None = f"summary_tables_{PROBLEM_CLASS}.json"
TABLE_JSON: str | None = None
table = ResultsDatabase(TABLE_JSON, problem_class=PROBLEM_CLASS)

# %% [markdown]
# ## Setup table with training data and min-max cuts.

# %%
if TABLE_JSON is None:

    def ignore_results(filename: str, results: dict[str, Any]) -> bool:
        """Ignore Parameter Transfer results for the tables."""
        if "PT_" in filename:
            return True

        # Ignore Fixed Angles if we are creating the MIS table.
        if PROBLEM_CLASS == "MIS" and "FA_" in filename:
            return True
        return False

    # Add training data. Only the "best" results are kept, per graph, trainer config
    # file, and depth.
    for path in [
        "../../data/training/random_regular",
        "../../data/training/heavy_hex",
        "../../data/training/line_to_full",
        "../../data/training/erdos_renyi",
    ]:
        table.add_data(path, ignore_file_function=ignore_results)
# Out:
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_101122_004N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_101122_004N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_092156_001N20R4R_MC_LR_SV_angle_opt_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_092156_001N20R4R_MC_LR_SV_angle_opt_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_145025_001N100R4R_MC_LR_PP_angleOptMW4_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_145025_001N100R4R_MC_LR_PP_angleOptMW4_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_095217_004N14R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_095217_004N14R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_095147_006N18R9R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_095147_006N18R9R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_093153_001N20R7R_MC_LR_SV_angle_opt_3.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_093153_001N20R7R_MC_LR_SV_angle_opt_3.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_040651_001N100R6R_MC_LR_MPSAer_angleOptBD16_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_040651_001N100R6R_MC_LR_MPSAer_angleOptBD16_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_094235_001N20R5R_MC_LR_SV_angle_opt_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_094235_001N20R5R_MC_LR_SV_angle_opt_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_114108_001N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_114108_001N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102151_009N12R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102151_009N12R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102136_001N20R7R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102136_001N20R7R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_025832_001N100R9R_MC_LR_MPSAer_angleOptBD16_6.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_025832_001N100R9R_MC_LR_MPSAer_angleOptBD16_6.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102611_008N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102611_008N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_092337_001N20R7R_MC_LR_SV_angle_opt_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_092337_001N20R7R_MC_LR_SV_angle_opt_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_095534_006N10R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_095534_006N10R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_145610_001N100R4R_MC_LR_PP_angleOptMW4_3.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_145610_001N100R4R_MC_LR_PP_angleOptMW4_3.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_084750_001N100R9R_MC_LR_MPS_angleOptBD16_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_084750_001N100R9R_MC_LR_MPS_angleOptBD16_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102239_002N16R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102239_002N16R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_043714_001N100R5R_MC_LR_MPSAer_angleOptBD16_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_043714_001N100R5R_MC_LR_MPSAer_angleOptBD16_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_111706_001N20R5R_MC_LR_SV_angle_opt_9.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_111706_001N20R5R_MC_LR_SV_angle_opt_9.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_094853_007N17R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_094853_007N17R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_015608_001N100R8R_MC_LR_MPSAer_angleOptBD16_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_015608_001N100R8R_MC_LR_MPSAer_angleOptBD16_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_101926_006N19R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_101926_006N19R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260501_225724_000N100R3R_MC_LR_MPS_angle_optBD16_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260501_225724_000N100R3R_MC_LR_MPS_angle_optBD16_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_101815_007N12R7R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_101815_007N12R7R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_214228_001N100R7R_MC_LR_PP_angleOptMW3_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_214228_001N100R7R_MC_LR_PP_angleOptMW3_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102755_001N14R4R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102755_001N14R4R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_011019_001N100R5R_MC_LR_MPSAer_angleOptBD16_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_011019_001N100R5R_MC_LR_MPSAer_angleOptBD16_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_212212_001N100R6R_MC_LR_PP_angleOptMW3_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_212212_001N100R6R_MC_LR_PP_angleOptMW3_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_063406_001N100R8R_MC_LR_MPS_angleOptBD16_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_063406_001N100R8R_MC_LR_MPS_angleOptBD16_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_101849_007N10R4R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_101849_007N10R4R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_011057_001N100R9R_MC_LR_MPSAer_angleOptBD16_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_011057_001N100R9R_MC_LR_MPSAer_angleOptBD16_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102311_007N12R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102311_007N12R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102050_006N10R9R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102050_006N10R9R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_005814_001N100R6R_MC_LR_MPSAer_angleOptBD16_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_005814_001N100R6R_MC_LR_MPSAer_angleOptBD16_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260429_174912_006N40R3R_MC_LR_MPS_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260429_174912_006N40R3R_MC_LR_MPS_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260429_163521_008N40R3R_MC_LR_MPSAer_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260429_163521_008N40R3R_MC_LR_MPSAer_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_095128_006N16R5R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_095128_006N16R5R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_221148_001N100R9R_MC_LR_PP_angleOptMW3_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_221148_001N100R9R_MC_LR_PP_angleOptMW3_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_104035_001N20R9R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_104035_001N20R9R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_152810_001N100R5R_MC_LR_PP_angleOptMW4_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_152810_001N100R5R_MC_LR_PP_angleOptMW4_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_214643_001N100R6R_MC_LR_PP_angleOptMW3_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_214643_001N100R6R_MC_LR_PP_angleOptMW3_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_055024_001N100R5R_MC_LR_MPS_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_055024_001N100R5R_MC_LR_MPS_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_145400_001N100R5R_MC_LR_PP_angleOptMW4_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_145400_001N100R5R_MC_LR_PP_angleOptMW4_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_095428_001N20R3R_MC_LR_SV_angle_opt_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_095428_001N20R3R_MC_LR_SV_angle_opt_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_005834_001N100R5R_MC_LR_MPSAer_angleOptBD16_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_005834_001N100R5R_MC_LR_MPSAer_angleOptBD16_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_042103_001N100R7R_MC_LR_MPSAer_angleOptBD16_9.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_042103_001N100R7R_MC_LR_MPSAer_angleOptBD16_9.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_060902_001N100R7R_MC_LR_MPS_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_060902_001N100R7R_MC_LR_MPS_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_032732_001N100R6R_MC_LR_MPSAer_angleOptBD16_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_032732_001N100R6R_MC_LR_MPSAer_angleOptBD16_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_013840_001N100R3R_MC_LR_MPSAer_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_013840_001N100R3R_MC_LR_MPSAer_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_212151_001N100R7R_MC_LR_PP_angleOptMW3_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_212151_001N100R7R_MC_LR_PP_angleOptMW3_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_011045_001N100R6R_MC_LR_MPSAer_angleOptBD16_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_011045_001N100R6R_MC_LR_MPSAer_angleOptBD16_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102914_001N14R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102914_001N14R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_105204_001N20R3R_MC_LR_SV_angle_opt_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_105204_001N20R3R_MC_LR_SV_angle_opt_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_095824_001N10R5R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_095824_001N10R5R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_151300_001N100R4R_MC_LR_PP_angleOptMW4_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_151300_001N100R4R_MC_LR_PP_angleOptMW4_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_054944_001N100R8R_MC_LR_MPS_angleOptBD16_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_054944_001N100R8R_MC_LR_MPS_angleOptBD16_1.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260429_165323_001N40R3R_MC_LR_MPSAer_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260429_165323_001N40R3R_MC_LR_MPSAer_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260429_174242_007N40R3R_MC_LR_MPS_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260429_174242_007N40R3R_MC_LR_MPS_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_071543_001N100R9R_MC_LR_MPS_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_071543_001N100R9R_MC_LR_MPS_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_221356_001N100R6R_MC_LR_PP_angleOptMW3_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_221356_001N100R6R_MC_LR_PP_angleOptMW3_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_094725_001N12R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_094725_001N12R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_040928_001N100R8R_MC_LR_MPSAer_angleOptBD16_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_040928_001N100R8R_MC_LR_MPSAer_angleOptBD16_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_051806_001N100R7R_MC_LR_MPS_angleOptBD16_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_051806_001N100R7R_MC_LR_MPS_angleOptBD16_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260429_173752_000N40R3R_MC_LR_MPS_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260429_173752_000N40R3R_MC_LR_MPS_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_104506_007N19R4R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_104506_007N19R4R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_100512_007N16R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_100512_007N16R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_053436_001N100R4R_MC_LR_MPS_angleOptBD16_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_053436_001N100R4R_MC_LR_MPS_angleOptBD16_8.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_114156_001N20R4R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_114156_001N20R4R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_022337_001N100R8R_MC_LR_MPSAer_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_022337_001N100R8R_MC_LR_MPSAer_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260429_163543_005N40R3R_MC_LR_MPSAer_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260429_163543_005N40R3R_MC_LR_MPSAer_angle_optBD32_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102858_006N18R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102858_006N18R6R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_103252_000N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_103252_000N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_063229_001N100R7R_MC_LR_MPS_angleOptBD16_6.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_063229_001N100R7R_MC_LR_MPS_angleOptBD16_6.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_213321_001N100R9R_MC_LR_PP_angleOptMW3_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_213321_001N100R9R_MC_LR_PP_angleOptMW3_4.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_100621_009N16R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_100621_009N16R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_102856_009N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_102856_009N20R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_214054_001N100R9R_MC_LR_PP_angleOptMW3_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_214054_001N100R9R_MC_LR_PP_angleOptMW3_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260429_181102_000N40R3R_MC_LR_PP_angle_optMW6_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260429_181102_000N40R3R_MC_LR_PP_angle_optMW6_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_213710_001N100R7R_MC_LR_PP_angleOptMW3_6.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_213710_001N100R7R_MC_LR_PP_angleOptMW3_6.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_PP_opt.json'), got 2 for file '../../data/training/random_regular/20260418_151318_001N100R3R_MC_LR_PP_angleOptMW4_9.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_PP_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_151318_001N100R3R_MC_LR_PP_angleOptMW4_9.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_092159_001N20R3R_MC_LR_SV_angle_opt_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_092159_001N20R3R_MC_LR_SV_angle_opt_2.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_104301_003N14R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_104301_003N14R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_022458_001N100R9R_MC_LR_MPSAer_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_022458_001N100R9R_MC_LR_MPSAer_angleOptBD16_5.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_021022_001N100R3R_MC_LR_MPSAer_angleOptBD16_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_021022_001N100R3R_MC_LR_MPSAer_angleOptBD16_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPSAer_opt.json'), got 2 for file '../../data/training/random_regular/20260418_053731_001N100R6R_MC_LR_MPSAer_angleOptBD16_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPSAer_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_053731_001N100R6R_MC_LR_MPSAer_angleOptBD16_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_SV_opt.json'), got 2 for file '../../data/training/random_regular/20260428_094940_003N18R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_SV_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260428_094940_003N18R3R_MC_LR_SV_angle_opt_10.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_051112_001N100R4R_MC_LR_MPS_angleOptBD16_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_051112_001N100R4R_MC_LR_MPS_angleOptBD16_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:553: UserWarning: Expected 1 iteration key for linear ramp ('LR_MPS_opt.json'), got 2 for file '../../data/training/random_regular/20260418_081311_001N100R9R_MC_LR_MPS_angleOptBD16_7.json'
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:558: UserWarning: Expected `["0"]` iteration keys for linear ramp ('LR_MPS_opt.json'), got ['0', '1'] instead for file '../../data/training/random_regular/20260418_081311_001N100R9R_MC_LR_MPS_angleOptBD16_7.json'
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 21
#      13 # Add training data. Only the "best" results are kept, per graph, trainer config
#      14 # file, and depth.
#      15 for path in [
#      16     "../../data/training/random_regular",
#      17     "../../data/training/heavy_hex",
#      18     "../../data/training/line_to_full",
#      19     "../../data/training/erdos_renyi",
#      20 ]:
# ---> 21     table.add_data(path, ignore_file_function=ignore_results)
#
# File ~/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:732, in ResultsDatabase.add_data(self, folder_name, ignore_file_function)
#     729 for filename in glob.glob(f"{folder_name}/*.json"):
#     730     filename = filename.replace("\\", "/")
# --> 732     with open(filename, "r") as fin:
#     733         result = json.load(fin)
#     735     # Determine file's problem class
#
# KeyboardInterrupt:

# %%
if TABLE_JSON is None and table.problem_class == "MC":
    # Add min- and max-cut data. If some graph instances do not have a minmax_cuts
    # entry, an error will be thrown later.
    table.add_minmax_cut_data("../../data/minmax_cuts/random_regular")
    table.add_minmax_cut_data("../../data/minmax_cuts/heavy_hex")
    table.add_minmax_cut_data("../../data/minmax_cuts/line_to_full")
    table.add_minmax_cut_data("../../data/minmax_cuts/erdos_renyi")

# %% [markdown]
# ## Identify missing min- and max-cuts data

# %%
if table.problem_class == "MC":
    missing_minmax_cuts = table.missing_minmax_cuts()
    if len(missing_minmax_cuts) == 0:
        print("All minmax_cuts data accounted for.")
    else:
        print(
            "The following graphs are missing min- and max-cuts data. "
            + "Generate them with compute_min_max_for_graph.py"
        )
        for _graph in missing_minmax_cuts:
            print("- {}".format(_graph))
else:
    print(f"Min-/Max-cut data not necessary for {table.problem_class} data.")
# Out:
# All minmax_cuts data accounted for.

# %% [markdown]
# ## List of methods per evaluation type

# %%
table.print_methods_by_evaluation()
# Out:
#       MPS (Aer)        |     MPS (Quimb)     |         PP         |         SV
# --------------------------------------------------------------------------------------
# FA_MPSAer_no_opt.json  | FA_MPS_no_opt.json  | FA_PP_no_opt.json  | FA_SV_no_opt.json
# FA_MPSAer_opt.json     | FA_MPS_opt.json     | FA_PP_opt.json     | FA_SV_opt.json
# F_MPSAer_opt.json      | F_MPS_opt.json      | F_PP_opt.json      | F_SV_opt.json
# I_MPSAer.json          | I_MPS.json          | I_PP.json          | I_SV.json
# LR_MPSAer.json         | LR_MPS.json         | LR_PP.json         | LR_SV.json
# LR_MPSAer_no_opt.json  | LR_MPS_no_opt.json  | LR_PP_no_opt.json  | LR_SV_no_opt.json
# LR_MPSAer_opt.json     | LR_MPS_opt.json     | LR_PP_opt.json     | LR_SV_opt.json
# RTS_MPSAer_opt.json    | RTS_MPS_opt.json    | RTS_PP_opt.json    | RTS_SV_opt.json
# TQA_MPSAer.json        | TQA_MPS.json        | TQA_PP.json        | TQA_SV.json
# TQA_MPSAer_no_opt.json | TQA_MPS_no_opt.json | TQA_PP_no_opt.json | TQA_SV_no_opt.json
# TQA_MPSAer_opt.json    | TQA_MPS_opt.json    | TQA_PP_opt.json    | TQA_SV_opt.json

# %% [markdown]
# ## Get raw data table

# %% [markdown]
# ### Define target instances

# %%
# Define target instances if we are filtering.
TARGET_INSTANCES: dict[EvaluationType, set[GraphKey] | dict[bool, set[GraphKey]]] | None
"""The target instances for all Summary Tables of this problem class.

We only filter instances here for MIS tables. MAXCUT filtering is done during
table generation using `only_common_instances`.
"""
if table.problem_class == "MIS":
    LARGE_INSTANCES: set[GraphKey] = set(
        [
            _graph_format.format(idx)
            for idx in range(10)
            for _graph_format in [
                "{:03}_100nodes_random3regular.json",
                "{:03}_7_3_heavyhex_144nodes_weighted.json",
                "{:03}_100nodes_2swap_layers.json",
                "{:03}_70nodes_erdosrenyi20percent.json",
            ]
        ]
    )
    SMALL_INSTANCES = {
        # 10x 20-node 20-percent Erdös-Rényi graphs
        "000_20nodes_erdosrenyi20percent.json",
        "001_20nodes_erdosrenyi20percent.json",
        "002_20nodes_erdosrenyi20percent.json",
        "003_20nodes_erdosrenyi20percent.json",
        "004_20nodes_erdosrenyi20percent.json",
        "005_20nodes_erdosrenyi20percent.json",
        "006_20nodes_erdosrenyi20percent.json",
        "007_20nodes_erdosrenyi20percent.json",
        "008_20nodes_erdosrenyi20percent.json",
        "009_20nodes_erdosrenyi20percent.json",
        # 10x 1-by-2 21-node Heavy-Hex graphs
        "000_1_2_heavyhex_21nodes_weighted.json",
        "001_1_2_heavyhex_21nodes_weighted.json",
        "002_1_2_heavyhex_21nodes_weighted.json",
        "003_1_2_heavyhex_21nodes_weighted.json",
        "004_1_2_heavyhex_21nodes_weighted.json",
        "005_1_2_heavyhex_21nodes_weighted.json",
        "006_1_2_heavyhex_21nodes_weighted.json",
        "007_1_2_heavyhex_21nodes_weighted.json",
        "008_1_2_heavyhex_21nodes_weighted.json",
        "009_1_2_heavyhex_21nodes_weighted.json",
        # 1x 20-node line-to-full graph per 1 to 10 swap layers, for total of 10x graphs
        "001_20nodes_1swap_layers.json",
        "001_20nodes_2swap_layers.json",
        "001_20nodes_3swap_layers.json",
        "001_20nodes_4swap_layers.json",
        "001_20nodes_5swap_layers.json",
        "001_20nodes_6swap_layers.json",
        "001_20nodes_7swap_layers.json",
        "001_20nodes_8swap_layers.json",
        "001_20nodes_9swap_layers.json",
        "001_20nodes_10swap_layers.json",
        # 1x 20-node random-regular graph per degree d=3,4,5,6,7,8,9 for a total of 7x graphs
        "001_20nodes_random3regular.json",
        "001_20nodes_random4regular.json",
        "001_20nodes_random5regular.json",
        "001_20nodes_random6regular.json",
        "001_20nodes_random7regular.json",
        "001_20nodes_random8regular.json",
        "001_20nodes_random9regular.json",
    }

    TARGET_INSTANCES = {
        "MPS": {
            False: LARGE_INSTANCES,
            True: LARGE_INSTANCES,
        },
        "PP": LARGE_INSTANCES,
        "SV": SMALL_INSTANCES,
    }
else:
    TARGET_INSTANCES = None

# %% [markdown]
# ### Define reference methods for filtering runs

# %%
# Determine reference methods for depth 10 tables.
REFERENCE_METHODS_10: (
    dict[
        EvaluationType | tuple[Literal["MPS"], bool],
        dict[
            GraphType,
            MethodConfigJSON,
        ],
    ]
    | None
)
"""Reference methods for depth 10 tables, only used for MAXCUT data.

These were found by hand, identifying methods with enough runs but that also
reduced the number of additional simulations to run.
"""
if table.problem_class == "MC":
    REFERENCE_METHODS_10 = {
        ("MPS", False): {
            "erdos_renyi": "F_MPS_opt.json",
            "heavy_hex": "F_MPS_opt.json",
            "line_to_full": "LR_MPS.json",
            "random_regular": "FA_MPS_opt.json",
        },
        ("MPS", True): {
            "erdos_renyi": "F_MPSAer_opt.json",
            "heavy_hex": "F_MPSAer_opt.json",
            "line_to_full": "LR_MPSAer.json",
            "random_regular": "FA_MPSAer_opt.json",
        },
        "SV": {
            "erdos_renyi": "TQA_SV_opt.json",
            "heavy_hex": "F_SV_opt.json",
            "line_to_full": "LR_SV.json",
            "random_regular": "TQA_SV_opt.json",
        },
        "PP": {
            "erdos_renyi": "TQA_PP_opt.json",
            "heavy_hex": "TQA_PP_opt.json",
            "line_to_full": "TQA_PP_opt.json",
            "random_regular": "TQA_PP_opt.json",
        },
    }  # type: ignore[assignment]
elif table.problem_class == "MIS":
    REFERENCE_METHODS_10 = None
else:
    raise NotImplementedError(
        "Cannot determine reference methods for problem class {!r}.".format(
            table.problem_class
        )
    )

# %% [markdown]
# ### Define number of nodes for filtering runs

# %%
NUM_NODES: Iterable[int] | dict[str, Iterable[int] | dict[bool, Iterable[int]]] | None
if table.problem_class == "MIS":
    NUM_NODES = {
        "MPS": {True: [70, 100, 144], False: [70, 100, 144]},
        "PP": [70, 100, 144],
        "SV": [20, 21],
    }
else:
    NUM_NODES = None

# %%
# Only select results with the best energy per config and instance:
table = table.only_best_parameters("config")

if TARGET_INSTANCES is not None or NUM_NODES is not None:
    table = table.filter_by(
        instance_filter=TARGET_INSTANCES,
        num_nodes=NUM_NODES,
    )


# This is the _raw_ table with all results
df: pd.DataFrame = table.to_dataframe()
df
# Out:
#                                     instance  num_nodes      graph_type  \
# 0            007_18nodes_random6regular.json         18  random_regular
# 1            007_18nodes_random6regular.json         18  random_regular
# 2            007_18nodes_random6regular.json         18  random_regular
# 3            007_18nodes_random6regular.json         18  random_regular
# 4            007_18nodes_random6regular.json         18  random_regular
# ...                                      ...        ...             ...
# 106447  003_40nodes_erdosrenyi20percent.json         40     erdos_renyi
# 106448  003_40nodes_erdosrenyi20percent.json         40     erdos_renyi
# 106449  001_20nodes_erdosrenyi50percent.json         20     erdos_renyi
# 106450  001_20nodes_erdosrenyi40percent.json         20     erdos_renyi
# 106451  001_19nodes_erdosrenyi50percent.json         19     erdos_renyi
#
#           trainer_config        method  depth     energy  \
# 0              I_SV.json        I.json      1   5.648554
# 1              I_SV.json        I.json      2   7.912167
# 2              I_SV.json        I.json      3   9.295293
# 3              I_SV.json        I.json      4  10.200031
# 4              I_SV.json        I.json      5  10.698477
# ...                  ...           ...    ...        ...
# 106447  RTS_MPS_opt.json  RTS_opt.json      9  36.721000
# 106448  RTS_MPS_opt.json  RTS_opt.json     10  37.045379
# 106449        LR_SV.json       LR.json     10  12.372434
# 106450        LR_SV.json       LR.json     10  12.766411
# 106451        LR_SV.json       LR.json     10  13.302642
#
#                           trainer evaluation evaluation_label  ...  \
# 0                    ScipyTrainer         SV               SV  ...
# 1                    ScipyTrainer         SV               SV  ...
# 2                    ScipyTrainer         SV               SV  ...
# 3                    ScipyTrainer         SV               SV  ...
# 4                    ScipyTrainer         SV               SV  ...
# ...                           ...        ...              ...  ...
# 106447    TransitionStatesTrainer        MPS      MPS (Quimb)  ...
# 106448  RecursiveTransitionStates        MPS      MPS (Quimb)  ...
# 106449                 TQATrainer         SV               SV  ...
# 106450                 TQATrainer         SV               SV  ...
# 106451                 TQATrainer         SV               SV  ...
#
#                                                  metadata result_index  \
# 0       {'iteration': '1', 'version': 13, 'evaluator':...            0
# 1       {'iteration': '2', 'version': 13, 'evaluator':...            0
# 2       {'iteration': '3', 'version': 13, 'evaluator':...            0
# 3       {'iteration': '4', 'version': 13, 'evaluator':...            0
# 4       {'iteration': '5', 'version': 13, 'evaluator':...            0
# ...                                                   ...          ...
# 106447  {'iteration': '9', 'version': 33, 'evaluator':...            0
# 106448  {'iteration': '1', 'version': 33, 'evaluator':...            0
# 106449  {'iteration': '0', 'version': 24, 'evaluator':...            0
# 106450  {'iteration': '0', 'version': 24, 'evaluator':...            0
# 106451  {'iteration': '0', 'version': 24, 'evaluator':...            0
#
#               run_datetime result_key_index  approximation_ratio  \
# 0      2025-09-28 07:49:02              1.0             0.816214
# 1      2025-09-28 07:49:02              2.2             0.872804
# 2      2025-09-28 07:49:02              3.2             0.907382
# 3      2025-09-28 07:49:02              4.2             0.930001
# 4      2025-09-28 07:49:02              5.2             0.942462
# ...                    ...              ...                  ...
# 106447 2026-05-02 05:36:41              9.1             0.968769
# 106448 2026-05-02 05:36:41              1.0             0.971449
# 106449 2025-12-10 10:42:07              0.0             0.965122
# 106450 2025-12-10 10:40:33              0.0             0.947431
# 106451 2025-12-10 10:37:45              0.0             0.938377
#
#        mps_bond_dimension  mps_threshold pp_max_weight  pp_min_abs_coeff  \
# 0                     NaN            NaN           NaN               NaN
# 1                     NaN            NaN           NaN               NaN
# 2                     NaN            NaN           NaN               NaN
# 3                     NaN            NaN           NaN               NaN
# 4                     NaN            NaN           NaN               NaN
# ...                   ...            ...           ...               ...
# 106447               16.0   1.000000e-10           NaN               NaN
# 106448               16.0   1.000000e-10           NaN               NaN
# 106449                NaN            NaN           NaN               NaN
# 106450                NaN            NaN           NaN               NaN
# 106451                NaN            NaN           NaN               NaN
#
#         fa_degree
# 0            None
# 1            None
# 2            None
# 3            None
# 4            None
# ...           ...
# 106447       None
# 106448       None
# 106449       None
# 106450       None
# 106451       None
#
# [106452 rows x 25 columns]

# %% [markdown]
# ## Get formatted and pivoted table and styler
#
# With Pandas, dataframes are formatted with Stylers.
# `qaoa_parameter_setting.utils.database.summary_table_formatter.formatted_styler_for` automatically
# stylises the Styler and returns the pivoted dataframe and Styler.

# %% [markdown]
# ### Example summary table with `"text"` formatting
#
# The following cells format the summary results into a single table suitable for
# Jupyter notebooks. Later cells will format the table for LaTeX and save them to
# a file.
#
# As we can generate tables for both MAXCUT and MIS, we use `performance_metric`
# to store the field name used to quantify performance.

# %%
performance_metric: Literal["approximation_ratio", "energy"]
if table.problem_class == "MC":
    performance_metric = "approximation_ratio"
elif table.problem_class == "MIS":
    performance_metric = "energy"
else:
    raise NotImplementedError(
        "Performance summary tables not implemented for {!r} problem class.".format(
            table.problem_class
        )
    )

# %% [markdown]
# #### MAXCUT Approximation Ratio or MIS Normalized Energy

# %%
pivot, styler, _ = formatted_styler_for(
    table,
    depths=10,
    agg_values=performance_metric,
    with_fancy_values=True,
    cmap={"MPS (Aer)": "BuPu", "MPS (Quimb)": "YlOrBr", "PP": "YlGn", "SV": "PuBu"},
    precision=2,
    missing_data_str="-",
    target_format="text",
    show_empty_rows=True,
    # exclude_methods=["RTS", "TS"],
)
styler
# Out:
# <style type="text/css">
# #T_6c4dd_row0_col0, #T_6c4dd_row1_col0, #T_6c4dd_row11_col0, #T_6c4dd_row11_col1, #T_6c4dd_row12_col0, #T_6c4dd_row12_col1, #T_6c4dd_row22_col0, #T_6c4dd_row23_col0, #T_6c4dd_row33_col1, #T_6c4dd_row34_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
#   color: black;
# }
# #T_6c4dd_row0_col1 {
#   background-color: #8a59a8;
#   color: #f1f1f1;
# }
# #T_6c4dd_row0_col2 {
#   background-color: #6e096a;
#   color: #f1f1f1;
# }
# #T_6c4dd_row0_col3 {
#   background-color: #4f004d;
#   color: #f1f1f1;
# }
# #T_6c4dd_row1_col1 {
#   background-color: #8c6ab1;
#   color: #f1f1f1;
# }
# #T_6c4dd_row1_col2 {
#   background-color: #821982;
#   color: #f1f1f1;
# }
# #T_6c4dd_row1_col3 {
#   background-color: #5a0457;
#   color: #f1f1f1;
# }
# #T_6c4dd_row2_col0 {
#   background-color: #9fbcda;
#   color: #000000;
# }
# #T_6c4dd_row2_col1 {
#   background-color: #8c93c4;
#   color: #f1f1f1;
# }
# #T_6c4dd_row2_col2 {
#   background-color: #a3bfdc;
#   color: #000000;
# }
# #T_6c4dd_row2_col3 {
#   background-color: #8c88bf;
#   color: #f1f1f1;
# }
# #T_6c4dd_row3_col0 {
#   background-color: #831d85;
#   color: #f1f1f1;
# }
# #T_6c4dd_row3_col1, #T_6c4dd_row5_col2 {
#   background-color: #88459f;
#   color: #f1f1f1;
# }
# #T_6c4dd_row3_col2, #T_6c4dd_row4_col2 {
#   background-color: #7c0e78;
#   color: #f1f1f1;
# }
# #T_6c4dd_row3_col3 {
#   background-color: #8b62ad;
#   color: #f1f1f1;
# }
# #T_6c4dd_row4_col0 {
#   background-color: #6c0968;
#   color: #f1f1f1;
# }
# #T_6c4dd_row4_col1 {
#   background-color: #8b60ac;
#   color: #f1f1f1;
# }
# #T_6c4dd_row4_col3, #T_6c4dd_row7_col0 {
#   background-color: #770c73;
#   color: #f1f1f1;
# }
# #T_6c4dd_row5_col0 {
#   background-color: #831c84;
#   color: #f1f1f1;
# }
# #T_6c4dd_row5_col1 {
#   background-color: #883e9b;
#   color: #f1f1f1;
# }
# #T_6c4dd_row5_col3 {
#   background-color: #863394;
#   color: #f1f1f1;
# }
# #T_6c4dd_row6_col0 {
#   background-color: #8a55a7;
#   color: #f1f1f1;
# }
# #T_6c4dd_row6_col1 {
#   background-color: #9dbad9;
#   color: #000000;
# }
# #T_6c4dd_row6_col2 {
#   background-color: #88419d;
#   color: #f1f1f1;
# }
# #T_6c4dd_row6_col3 {
#   background-color: #cfdfed;
#   color: #000000;
# }
# #T_6c4dd_row7_col1 {
#   background-color: #8c94c5;
#   color: #f1f1f1;
# }
# #T_6c4dd_row7_col2 {
#   background-color: #831f86;
#   color: #f1f1f1;
# }
# #T_6c4dd_row7_col3, #T_6c4dd_row8_col3 {
#   background-color: #832088;
#   color: #f1f1f1;
# }
# #T_6c4dd_row8_col0 {
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_6c4dd_row8_col1 {
#   background-color: #8c6eb3;
#   color: #f1f1f1;
# }
# #T_6c4dd_row8_col2 {
#   background-color: #8a58a8;
#   color: #f1f1f1;
# }
# #T_6c4dd_row9_col0 {
#   background-color: #8c81bc;
#   color: #f1f1f1;
# }
# #T_6c4dd_row9_col1 {
#   background-color: #8c79b8;
#   color: #f1f1f1;
# }
# #T_6c4dd_row9_col2 {
#   background-color: #8c8fc2;
#   color: #f1f1f1;
# }
# #T_6c4dd_row9_col3 {
#   background-color: #8947a0;
#   color: #f1f1f1;
# }
# #T_6c4dd_row10_col0 {
#   background-color: #9ab4d6;
#   color: #000000;
# }
# #T_6c4dd_row10_col1 {
#   background-color: #a7c2dd;
#   color: #000000;
# }
# #T_6c4dd_row10_col2 {
#   background-color: #c8daea;
#   color: #000000;
# }
# #T_6c4dd_row10_col3 {
#   background-color: #96abd1;
#   color: #f1f1f1;
# }
# #T_6c4dd_row11_col2, #T_6c4dd_row15_col0 {
#   background-color: #762a05;
#   color: #f1f1f1;
# }
# #T_6c4dd_row11_col3 {
#   background-color: #692606;
#   color: #f1f1f1;
# }
# #T_6c4dd_row12_col2, #T_6c4dd_row14_col0 {
#   background-color: #782a05;
#   color: #f1f1f1;
# }
# #T_6c4dd_row12_col3 {
#   background-color: #742905;
#   color: #f1f1f1;
# }
# #T_6c4dd_row13_col0, #T_6c4dd_row20_col1 {
#   background-color: #fed36f;
#   color: #000000;
# }
# #T_6c4dd_row13_col1 {
#   background-color: #fee596;
#   color: #000000;
# }
# #T_6c4dd_row13_col2 {
#   background-color: #e86c12;
#   color: #f1f1f1;
# }
# #T_6c4dd_row13_col3 {
#   background-color: #e76b11;
#   color: #f1f1f1;
# }
# #T_6c4dd_row14_col1 {
#   background-color: #f5841e;
#   color: #f1f1f1;
# }
# #T_6c4dd_row14_col2 {
#   background-color: #832d05;
#   color: #f1f1f1;
# }
# #T_6c4dd_row14_col3, #T_6c4dd_row18_col3 {
#   background-color: #cd4d03;
#   color: #f1f1f1;
# }
# #T_6c4dd_row15_col1 {
#   background-color: #feb340;
#   color: #000000;
# }
# #T_6c4dd_row15_col2 {
#   background-color: #8e3104;
#   color: #f1f1f1;
# }
# #T_6c4dd_row15_col3 {
#   background-color: #892f05;
#   color: #f1f1f1;
# }
# #T_6c4dd_row16_col0 {
#   background-color: #882f05;
#   color: #f1f1f1;
# }
# #T_6c4dd_row16_col1 {
#   background-color: #feb945;
#   color: #000000;
# }
# #T_6c4dd_row16_col2, #T_6c4dd_row19_col3 {
#   background-color: #a13804;
#   color: #f1f1f1;
# }
# #T_6c4dd_row16_col3, #T_6c4dd_row19_col0 {
#   background-color: #cb4b02;
#   color: #f1f1f1;
# }
# #T_6c4dd_row17_col0 {
#   background-color: #9c3604;
#   color: #f1f1f1;
# }
# #T_6c4dd_row17_col1 {
#   background-color: #fff3b4;
#   color: #000000;
# }
# #T_6c4dd_row17_col2 {
#   background-color: #c64902;
#   color: #f1f1f1;
# }
# #T_6c4dd_row17_col3 {
#   background-color: #feda7e;
#   color: #000000;
# }
# #T_6c4dd_row18_col0 {
#   background-color: #792b05;
#   color: #f1f1f1;
# }
# #T_6c4dd_row18_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_6c4dd_row18_col2 {
#   background-color: #ac3d03;
#   color: #f1f1f1;
# }
# #T_6c4dd_row19_col1 {
#   background-color: #fec859;
#   color: #000000;
# }
# #T_6c4dd_row19_col2 {
#   background-color: #be4503;
#   color: #f1f1f1;
# }
# #T_6c4dd_row20_col0 {
#   background-color: #ee7617;
#   color: #f1f1f1;
# }
# #T_6c4dd_row20_col2 {
#   background-color: #db5d0b;
#   color: #f1f1f1;
# }
# #T_6c4dd_row20_col3 {
#   background-color: #d45507;
#   color: #f1f1f1;
# }
# #T_6c4dd_row21_col0 {
#   background-color: #fea433;
#   color: #000000;
# }
# #T_6c4dd_row21_col1 {
#   background-color: #fff4b6;
#   color: #000000;
# }
# #T_6c4dd_row21_col2 {
#   background-color: #fe9e2d;
#   color: #000000;
# }
# #T_6c4dd_row21_col3 {
#   background-color: #fec95b;
#   color: #000000;
# }
# #T_6c4dd_row22_col1 {
#   background-color: #0a703a;
#   color: #f1f1f1;
# }
# #T_6c4dd_row22_col2, #T_6c4dd_row24_col3, #T_6c4dd_row26_col2 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_6c4dd_row22_col3 {
#   background-color: #12763d;
#   color: #f1f1f1;
# }
# #T_6c4dd_row23_col1, #T_6c4dd_row30_col3 {
#   background-color: #248644;
#   color: #f1f1f1;
# }
# #T_6c4dd_row23_col2 {
#   background-color: #5ab76a;
#   color: #f1f1f1;
# }
# #T_6c4dd_row23_col3 {
#   background-color: #177b3f;
#   color: #f1f1f1;
# }
# #T_6c4dd_row24_col0 {
#   background-color: #258745;
#   color: #f1f1f1;
# }
# #T_6c4dd_row24_col1 {
#   background-color: #288a47;
#   color: #f1f1f1;
# }
# #T_6c4dd_row24_col2 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_6c4dd_row25_col0 {
#   background-color: #086e3a;
#   color: #f1f1f1;
# }
# #T_6c4dd_row25_col1 {
#   background-color: #026a38;
#   color: #f1f1f1;
# }
# #T_6c4dd_row25_col2, #T_6c4dd_row29_col1 {
#   background-color: #359c53;
#   color: #f1f1f1;
# }
# #T_6c4dd_row25_col3, #T_6c4dd_row29_col0 {
#   background-color: #2f934d;
#   color: #f1f1f1;
# }
# #T_6c4dd_row26_col0 {
#   background-color: #006435;
#   color: #f1f1f1;
# }
# #T_6c4dd_row26_col1 {
#   background-color: #11753d;
#   color: #f1f1f1;
# }
# #T_6c4dd_row26_col3 {
#   background-color: #197c40;
#   color: #f1f1f1;
# }
# #T_6c4dd_row27_col0 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# #T_6c4dd_row27_col1 {
#   background-color: #167a3f;
#   color: #f1f1f1;
# }
# #T_6c4dd_row27_col2 {
#   background-color: #49af61;
#   color: #f1f1f1;
# }
# #T_6c4dd_row27_col3 {
#   background-color: #218242;
#   color: #f1f1f1;
# }
# #T_6c4dd_row28_col0 {
#   background-color: #0c723b;
#   color: #f1f1f1;
# }
# #T_6c4dd_row28_col1 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_6c4dd_row28_col2 {
#   background-color: #4ab062;
#   color: #f1f1f1;
# }
# #T_6c4dd_row28_col3 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_6c4dd_row29_col2 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_6c4dd_row29_col3 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_6c4dd_row30_col0 {
#   background-color: #268846;
#   color: #f1f1f1;
# }
# #T_6c4dd_row30_col1 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_6c4dd_row30_col2 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_6c4dd_row31_col0 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_6c4dd_row31_col1 {
#   background-color: #329850;
#   color: #f1f1f1;
# }
# #T_6c4dd_row31_col2 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_6c4dd_row31

# %% [markdown]
# #### Number of instances and nodes

# %%
pivot, styler, _ = formatted_styler_for(
    table,
    depths=10,
    num_nodes=None,
    agg_values="num_instances",
    with_fancy_values=True,
    cmap="Greens",
    precision=0,
    missing_data_str="-",
    target_format="text",
    show_empty_rows=True,
    # exclude_methods=["RTS", "TS"],
)
styler
# Out:
# <style type="text/css">
# #T_1b08f_row0_col0, #T_1b08f_row1_col0, #T_1b08f_row11_col0, #T_1b08f_row11_col1, #T_1b08f_row12_col0, #T_1b08f_row12_col1, #T_1b08f_row22_col0, #T_1b08f_row23_col0, #T_1b08f_row33_col1, #T_1b08f_row34_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
#   color: black;
# }
# #T_1b08f_row0_col1, #T_1b08f_row1_col1, #T_1b08f_row2_col0, #T_1b08f_row2_col1, #T_1b08f_row3_col0, #T_1b08f_row3_col1, #T_1b08f_row4_col0, #T_1b08f_row4_col1, #T_1b08f_row5_col0, #T_1b08f_row6_col0, #T_1b08f_row6_col1, #T_1b08f_row7_col0, #T_1b08f_row7_col1, #T_1b08f_row8_col0, #T_1b08f_row8_col1, #T_1b08f_row9_col0, #T_1b08f_row9_col1, #T_1b08f_row10_col0, #T_1b08f_row10_col1, #T_1b08f_row13_col0, #T_1b08f_row14_col0, #T_1b08f_row15_col0, #T_1b08f_row16_col0, #T_1b08f_row16_col1, #T_1b08f_row17_col0, #T_1b08f_row18_col0, #T_1b08f_row19_col0, #T_1b08f_row20_col0, #T_1b08f_row21_col0, #T_1b08f_row24_col0, #T_1b08f_row25_col0, #T_1b08f_row26_col0, #T_1b08f_row27_col0, #T_1b08f_row28_col0, #T_1b08f_row29_col0, #T_1b08f_row30_col0, #T_1b08f_row31_col0, #T_1b08f_row32_col0, #T_1b08f_row35_col1, #T_1b08f_row36_col1, #T_1b08f_row37_col1, #T_1b08f_row38_col1, #T_1b08f_row39_col1, #T_1b08f_row40_col1, #T_1b08f_row41_col1, #T_1b08f_row42_col1, #T_1b08f_row43_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_1b08f_row0_col2, #T_1b08f_row0_col3, #T_1b08f_row1_col2, #T_1b08f_row1_col3, #T_1b08f_row7_col3, #T_1b08f_row11_col3, #T_1b08f_row12_col3, #T_1b08f_row22_col3, #T_1b08f_row23_col3 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_1b08f_row2_col2, #T_1b08f_row3_col2, #T_1b08f_row4_col2, #T_1b08f_row5_col2, #T_1b08f_row6_col2, #T_1b08f_row7_col2, #T_1b08f_row8_col2, #T_1b08f_row9_col2, #T_1b08f_row10_col2 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_1b08f_row2_col3, #T_1b08f_row3_col3, #T_1b08f_row4_col3, #T_1b08f_row5_col3, #T_1b08f_row6_col3, #T_1b08f_row8_col3, #T_1b08f_row9_col3, #T_1b08f_row10_col3, #T_1b08f_row13_col3, #T_1b08f_row14_col3, #T_1b08f_row15_col3, #T_1b08f_row17_col3, #T_1b08f_row18_col3, #T_1b08f_row19_col3, #T_1b08f_row20_col3, #T_1b08f_row21_col3, #T_1b08f_row24_col3, #T_1b08f_row25_col3, #T_1b08f_row26_col3, #T_1b08f_row27_col3, #T_1b08f_row28_col3, #T_1b08f_row29_col3, #T_1b08f_row30_col3, #T_1b08f_row31_col3, #T_1b08f_row32_col3, #T_1b08f_row33_col0, #T_1b08f_row34_col0 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_1b08f_row5_col1, #T_1b08f_row13_col1, #T_1b08f_row14_col1, #T_1b08f_row15_col1, #T_1b08f_row17_col1, #T_1b08f_row18_col1, #T_1b08f_row19_col1, #T_1b08f_row20_col1, #T_1b08f_row21_col1, #T_1b08f_row22_col1, #T_1b08f_row23_col1, #T_1b08f_row24_col1, #T_1b08f_row25_col1, #T_1b08f_row26_col1, #T_1b08f_row27_col1, #T_1b08f_row28_col1, #T_1b08f_row29_col1, #T_1b08f_row30_col1, #T_1b08f_row31_col1, #T_1b08f_row32_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_1b08f_row11_col2, #T_1b08f_row12_col2, #T_1b08f_row15_col2, #T_1b08f_row16_col2, #T_1b08f_row16_col3, #T_1b08f_row17_col2, #T_1b08f_row18_col2, #T_1b08f_row22_col2, #T_1b08f_row23_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_1b08f_row13_col2, #T_1b08f_row14_col2, #T_1b08f_row19_col2, #T_1b08f_row20_col2, #T_1b08f_row21_col2, #T_1b08f_row24_col2, #T_1b08f_row25_col2, #T_1b08f_row26_col2, #T_1b08f_row28_col2, #T_1b08f_row29_col2, #T_1b08f_row30_col2, #T_1b08f_row31_col2, #T_1b08f_row32_col2 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_1b08f_row27_col2 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_1b08f_row33_col2, #T_1b08f_row34_col2 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_1b08f_row33_col3 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_1b08f_row34_col3 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_1b08f_row35_col0, #T_1b08f_row36_col0, #T_1b08f_row37_col0, #T_1b08f_row39_col0, #T_1b08f_row40_col0, #T_1b08f_row41_col0, #T_1b08f_row42_col0, #T_1b08f_row43_col0 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_1b08f_row35_col2, #T_1b08f_row36_col2, #T_1b08f_row42_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_1b08f_row35_col3, #T_1b08f_row36_col3 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_1b08f_row37_col2, #T_1b08f_row38_col2, #T_1b08f_row39_col2 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_1b08f_row37_col3, #T_1b08f_row39_col3, #T_1b08f_row41_col3, #T_1b08f_row43_col3 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_1b08f_row38_col0 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_1b08f_row38_col3 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_1b08f_row40_col2 {
#   background-color: #6dc072;
#   color: #000000;
# }
# #T_1b08f_row40_col3 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_1b08f_row41_col2, #T_1b08f_row43_col2 {
#   background-color: #00451c;
#   color: #f1f1f1;
# }
# #T_1b08f_row42_col3 {
#   background-color: #80ca80;
#   color: #000000;
# }
# </style>
# <table id="T_1b08f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >graph_type</th>
#       <th id="T_1b08f_level0_col0" class="col_heading level0 col0" >ER</th>
#       <th id="T_1b08f_level0_col1" class="col_heading level0 col1" >HH</th>
#       <th id="T_1b08f_level0_col2" class="col_heading level0 col2" >LB</th>
#       <th id="T_1b08f_level0_col3" class="col_heading level0 col3" >RR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b08f_level0_row0" class="row_heading level0 row0" rowspan="11">MPS (Aer)</th>
#       <th id="T_1b08f_level1_row0" class="row_heading level1 row0" >Fixed Angles*</th>
#       <td id="T_1b08f_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_1b08f_row0_col1" class="data row0 col1" >20 [39-144]</td>
#       <td id="T_1b08f_row0_col2" class="data row0 col2" >14 [100]</td>
#       <td id="T_1b08f_row0_col3" class="data row0 col3" >11 [40-100]</td>
#     </tr>
#     <tr>
#       <th id="T_1b08f_level1_row1" class="row_heading level1 row1" >Fixed Angles†</th>
#       <td id="T_1b08f_row1_col0" class="data row1 col0" >-</td>
#       <td id="T_1b08f_row1_col1" class="data row1 col1" >20 [39-144]</td>
#       <td id="T_1b08f_row1_col2" class="data row1 col2" >14 [100]</td>
#       <td id="T_1b08f_row1_col3" class="data row1 col3" >11 [40-100]</td>
#     </tr>
#     <tr>
#       <th id="T_1b08f_level1_row2" class="row_heading level1 row2" >Fourier*</th>
#       <td id="T_1b08f_row2_col0" class="data row2 col0" >20 [40-50]</td>
#       <td id="T_1b08f_row2_col1" class="data row2 col1" >20 [39-144]</td>
#       <td id="T_1b08f_row2_col2" class="data row2 col2" >50 [40-100]</td>
#       <td id="T_1b08f_row2_col3" class="data row2 col3" >17 [40-100]</td>
#     </tr>
#     <tr>
#       <th id="T_1b08f_level1_row3" class="row_heading level1 row3" >Interp.*</th>
#       <td id="T_1b08f_row3_col0" class="data row3 col0" >20 [40-50]</td>
#       <td id="T_1b08f_row3_col1" class="data row3 col1" >20 [39-144]</td>
#       <td id="T_1b08f_row3_col2" class="data row3 col2" >50 [40-100]</td>
#       <td id="T_1b08f_row3_col3" class="data row3 col3" >17 [40-100]</td>
#     </tr>
#     <tr>
#       <th id="T_1b08f_level1_row4" class="row_heading level1 row4" >Linear Ramp*</th>
#       <td id="T_1b08f_row4_col0" class="data row4 col0" >20 [40-50]</td>
#       <td id="T_1b08f_row4_col1" class="data row4 col1" >20 [39-144]</td>
#       <td id="T_1b08f_row4_col2" class="data row4 col2" >50 [40-100]</td>
#       <td id="T_1b08f_row4_col3" class="data row4 col3" >17 [40-100]</td>
#     </tr>
#     <tr>
#       <th id="T_1b08f_level1_row5" class="row_heading level1 row5" >Linear Ramp</th>
#       <td id="T_1b08f_row5_col0" class="data row5 col0" >20 [40-50]</td>
#       <td id="T_1b08f_row5_col1" class="data row5 col1" >30 [39-144]</td>
#       <td id="T_1b08f_row5_col2" class="data row5 col2" >50 [40-100]</td>
#       <td id="T_1b08f_row5_col3" class="data row5 col3" >17 [40-100]</td>
#     </tr>
#     <tr>
#       <th id="T_1b08f_level1_row6" class="row_heading level1 row6" >Linear Ramp†</th>
#       <td id="T_1b08f_row6_col0" class="data row6 col0" >20 [40-50]</td>
#       <td id="T_1b08f

# %% [markdown]
# ## Combined table

# %%
table_cmap = {
    (k1, k2): v if k2 == performance_metric else "RdPu"
    for k1, v in {
        "MPS (Aer)": "BuPu",
        "MPS (Quimb)": "YlOrBr",
        "PP": "YlGn",
        "SV": "PuBu",
    }.items()
    for k2 in [performance_metric, "num_instances"]
}
pivot, styler, cmap_ranges = formatted_styler_for(
    table,
    depths=10,
    agg_values=[performance_metric, "num_instances"],
    with_fancy_values=True,
    cmap=table_cmap,
    precision={performance_metric: 2, "num_instances": 0},
    missing_data_str="-",
    target_format="text",
    show_empty_rows=False,
    # exclude_methods=["RTS"],
)
styler
# Out:
# <style type="text/css">
# #T_4c838_row0_col0, #T_4c838_row0_col4, #T_4c838_row1_col0, #T_4c838_row1_col4, #T_4c838_row11_col0, #T_4c838_row11_col1, #T_4c838_row11_col4, #T_4c838_row11_col5, #T_4c838_row12_col0, #T_4c838_row12_col1, #T_4c838_row12_col4, #T_4c838_row12_col5, #T_4c838_row22_col0, #T_4c838_row22_col4, #T_4c838_row23_col0, #T_4c838_row23_col4, #T_4c838_row33_col1, #T_4c838_row33_col5, #T_4c838_row34_col1, #T_4c838_row34_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
#   color: black;
# }
# #T_4c838_row0_col1 {
#   background-color: #8a59a8;
#   color: #f1f1f1;
# }
# #T_4c838_row0_col2 {
#   background-color: #6e096a;
#   color: #f1f1f1;
# }
# #T_4c838_row0_col3 {
#   background-color: #4f004d;
#   color: #f1f1f1;
# }
# #T_4c838_row0_col5, #T_4c838_row1_col5, #T_4c838_row2_col4, #T_4c838_row2_col5, #T_4c838_row3_col4, #T_4c838_row3_col5, #T_4c838_row4_col4, #T_4c838_row5_col4, #T_4c838_row5_col5, #T_4c838_row6_col4, #T_4c838_row6_col5, #T_4c838_row7_col4, #T_4c838_row7_col5, #T_4c838_row8_col4, #T_4c838_row8_col5, #T_4c838_row9_col4, #T_4c838_row9_col5, #T_4c838_row10_col4, #T_4c838_row10_col5, #T_4c838_row13_col4, #T_4c838_row14_col4, #T_4c838_row15_col4, #T_4c838_row15_col5, #T_4c838_row16_col4, #T_4c838_row17_col4, #T_4c838_row18_col4, #T_4c838_row19_col4, #T_4c838_row20_col4, #T_4c838_row21_col4, #T_4c838_row24_col4, #T_4c838_row25_col4, #T_4c838_row26_col4, #T_4c838_row27_col4, #T_4c838_row28_col4, #T_4c838_row29_col4, #T_4c838_row30_col4, #T_4c838_row31_col4, #T_4c838_row32_col4, #T_4c838_row35_col5, #T_4c838_row36_col5, #T_4c838_row37_col5, #T_4c838_row38_col5, #T_4c838_row39_col5, #T_4c838_row40_col5, #T_4c838_row41_col5, #T_4c838_row42_col5, #T_4c838_row43_col5 {
#   background-color: #fff4f0;
#   color: #000000;
# }
# #T_4c838_row0_col6, #T_4c838_row0_col7, #T_4c838_row1_col6, #T_4c838_row1_col7, #T_4c838_row7_col7, #T_4c838_row11_col7, #T_4c838_row12_col7, #T_4c838_row22_col7, #T_4c838_row23_col7 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# #T_4c838_row1_col1 {
#   background-color: #8c6ab1;
#   color: #f1f1f1;
# }
# #T_4c838_row1_col2 {
#   background-color: #821982;
#   color: #f1f1f1;
# }
# #T_4c838_row1_col3 {
#   background-color: #5a0457;
#   color: #f1f1f1;
# }
# #T_4c838_row2_col0 {
#   background-color: #9fbcda;
#   color: #000000;
# }
# #T_4c838_row2_col1 {
#   background-color: #8c93c4;
#   color: #f1f1f1;
# }
# #T_4c838_row2_col2 {
#   background-color: #a3bfdc;
#   color: #000000;
# }
# #T_4c838_row2_col3 {
#   background-color: #8c88bf;
#   color: #f1f1f1;
# }
# #T_4c838_row2_col6, #T_4c838_row3_col6, #T_4c838_row4_col6, #T_4c838_row5_col6, #T_4c838_row6_col6, #T_4c838_row7_col6, #T_4c838_row8_col6, #T_4c838_row9_col6, #T_4c838_row10_col6 {
#   background-color: #feede9;
#   color: #000000;
# }
# #T_4c838_row2_col7, #T_4c838_row3_col7, #T_4c838_row4_col7, #T_4c838_row5_col7, #T_4c838_row6_col7, #T_4c838_row8_col7, #T_4c838_row9_col7, #T_4c838_row10_col7, #T_4c838_row13_col7, #T_4c838_row14_col7, #T_4c838_row16_col7, #T_4c838_row17_col7, #T_4c838_row18_col7, #T_4c838_row19_col7, #T_4c838_row20_col7, #T_4c838_row21_col7, #T_4c838_row24_col7, #T_4c838_row25_col7, #T_4c838_row26_col7, #T_4c838_row27_col7, #T_4c838_row28_col7, #T_4c838_row29_col7, #T_4c838_row30_col7, #T_4c838_row31_col7, #T_4c838_row32_col7, #T_4c838_row33_col4, #T_4c838_row34_col4 {
#   background-color: #fff5f1;
#   color: #000000;
# }
# #T_4c838_row3_col0 {
#   background-color: #831d85;
#   color: #f1f1f1;
# }
# #T_4c838_row3_col1, #T_4c838_row4_col2 {
#   background-color: #88459f;
#   color: #f1f1f1;
# }
# #T_4c838_row3_col2, #T_4c838_row5_col2 {
#   background-color: #7c0e78;
#   color: #f1f1f1;
# }
# #T_4c838_row3_col3 {
#   background-color: #8b62ad;
#   color: #f1f1f1;
# }
# #T_4c838_row4_col0 {
#   background-color: #831c84;
#   color: #f1f1f1;
# }
# #T_4c838_row4_col1 {
#   background-color: #883e9b;
#   color: #f1f1f1;
# }
# #T_4c838_row4_col3 {
#   background-color: #863394;
#   color: #f1f1f1;
# }
# #T_4c838_row4_col5, #T_4c838_row13_col5, #T_4c838_row14_col5, #T_4c838_row16_col5, #T_4c838_row17_col5, #T_4c838_row18_col5, #T_4c838_row19_col5, #T_4c838_row20_col5, #T_4c838_row21_col5, #T_4c838_row22_col5, #T_4c838_row23_col5, #T_4c838_row24_col5, #T_4c838_row25_col5, #T_4c838_row26_col5, #T_4c838_row27_col5, #T_4c838_row28_col5, #T_4c838_row29_col5, #T_4c838_row30_col5, #T_4c838_row31_col5, #T_4c838_row32_col5 {
#   background-color: #fff2ee;
#   color: #000000;
# }
# #T_4c838_row5_col0 {
#   background-color: #6c0968;
#   color: #f1f1f1;
# }
# #T_4c838_row5_col1 {
#   background-color: #8b60ac;
#   color: #f1f1f1;
# }
# #T_4c838_row5_col3, #T_4c838_row7_col0 {
#   background-color: #770c73;
#   color: #f1f1f1;
# }
# #T_4c838_row6_col0 {
#   background-color: #8a55a7;
#   color: #f1f1f1;
# }
# #T_4c838_row6_col1 {
#   background-color: #9dbad9;
#   color: #000000;
# }
# #T_4c838_row6_col2 {
#   background-color: #88419d;
#   color: #f1f1f1;
# }
# #T_4c838_row6_col3 {
#   background-color: #cfdfed;
#   color: #000000;
# }
# #T_4c838_row7_col1 {
#   background-color: #8c94c5;
#   color: #f1f1f1;
# }
# #T_4c838_row7_col2 {
#   background-color: #831f86;
#   color: #f1f1f1;
# }
# #T_4c838_row7_col3, #T_4c838_row9_col3 {
#   background-color: #832088;
#   color: #f1f1f1;
# }
# #T_4c838_row8_col0 {
#   background-color: #8c81bc;
#   color: #f1f1f1;
# }
# #T_4c838_row8_col1 {
#   background-color: #8c79b8;
#   color: #f1f1f1;
# }
# #T_4c838_row8_col2 {
#   background-color: #8c8fc2;
#   color: #f1f1f1;
# }
# #T_4c838_row8_col3 {
#   background-color: #8947a0;
#   color: #f1f1f1;
# }
# #T_4c838_row9_col0 {
#   background-color: #8b5daa;
#   color: #f1f1f1;
# }
# #T_4c838_row9_col1 {
#   background-color: #8c6eb3;
#   color: #f1f1f1;
# }
# #T_4c838_row9_col2 {
#   background-color: #8a58a8;
#   color: #f1f1f1;
# }
# #T_4c838_row10_col0 {
#   background-color: #9ab4d6;
#   color: #000000;
# }
# #T_4c838_row10_col1 {
#   background-color: #a7c2dd;
#   color: #000000;
# }
# #T_4c838_row10_col2 {
#   background-color: #c8daea;
#   color: #000000;
# }
# #T_4c838_row10_col3 {
#   background-color: #96abd1;
#   color: #f1f1f1;
# }
# #T_4c838_row11_col2, #T_4c838_row16_col0 {
#   background-color: #762a05;
#   color: #f1f1f1;
# }
# #T_4c838_row11_col3 {
#   background-color: #692606;
#   color: #f1f1f1;
# }
# #T_4c838_row11_col6, #T_4c838_row12_col6, #T_4c838_row15_col6, #T_4c838_row15_col7, #T_4c838_row16_col6, #T_4c838_row17_col6, #T_4c838_row18_col6, #T_4c838_row22_col6, #T_4c838_row23_col6 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_4c838_row12_col2, #T_4c838_row14_col0 {
#   background-color: #782a05;
#   color: #f1f1f1;
# }
# #T_4c838_row12_col3 {
#   background-color: #742905;
#   color: #f1f1f1;
# }
# #T_4c838_row13_col0, #T_4c838_row19_col1 {
#   background-color: #fed36f;
#   color: #000000;
# }
# #T_4c838_row13_col1 {
#   background-color: #fee596;
#   color: #000000;
# }
# #T_4c838_row13_col2 {
#   background-color: #e86c12;
#   color: #f1f1f1;
# }
# #T_4c838_row13_col3 {
#   background-color: #e76b11;
#   color: #f1f1f1;
# }
# #T_4c838_row13_col6, #T_4c838_row14_col6, #T_4c838_row19_col6, #T_4c838_row20_col6, #T_4c838_row21_col6, #T_4c838_row24_col6, #T_4c838_row25_col6, #T_4c838_row27_col6, #T_4c838_row28_col6, #T_4c838_row29_col6, #T_4c838_row30_col6, #T_4c838_row31_col6, #T_4c838_row32_col6 {
#   background-color: #fddedb;
#   color: #000000;
# }
# #T_4c838_row14_col1 {
#   background-color: #f5841e;
#   color: #f1f1f1;
# }
# #T_4c838_row14_col2 {
#   background-color: #832d05;
#   color: #f1f1f1;
# }
# #T_4c838_row14_col3, #T_4c838_row18_col3 {
#   background-color: #cd4d03;
#   color: #f1f1f1;
# }
# #T_4c838_row15_col0 {
#   background-color: #882f05;
#   color: #f1f1f1;
# }
# #T_4c838_row15_col1 {
#   background-color: #feb945;
#   color: #000000;
# }
# #T_4c838_row15_col2, #T_4c838_row20_col3 {
#   background-color: #a13804;
#   color: #f1f1f1;
# }
# #T_4c838_row15_col3, #T_4c838_row20_col0 {
#   background-color: #cb4b02;
#   color: #f1f1f1;
# }
# #T_4c838_row16_col1 {
#   background-color: #feb340;
#   color: #000000;
# }
# #T_4c838_row16_col2 {
#   background-color: #8e3104;
#   color: #f1f1f1;
# }
# #T_4c838_row16_col3 {
#   background-color: #892f05;
#   color: #f1f1f1;
# }
# #T_4c838_row17_col0 {
#   background-color: #9c3604;
#   color: #f1f1f1;
# }
# #T_4c838_row17_col1 {
#   background-color: #fff3b4;
#   color: #000000;
# }
# #T_4c838_row17_col2 {
#   background-color: #c64902;

# %%
table_cmap = {
    (k1, k2): v if k2 == performance_metric else "RdPu"
    for k1, v in {
        "MPS (Aer)": "BuPu",
        "MPS (Quimb)": "YlOrBr",
        "PP": "YlGn",
        "SV": "PuBu",
    }.items()
    for k2 in [performance_metric, "num_instances"]
}
pivot, styler, cmap_ranges = formatted_styler_for(
    table,
    depths=6,
    num_nodes={
        "MPS (Aer)": [70, 100],
        "MPS (Quimb)": [70, 100],
        "PP": [70, 100],
        "SV": 20,
    },
    agg_values=[performance_metric, "num_instances"],
    with_fancy_values=True,
    cmap=table_cmap,
    precision={performance_metric: 2, "num_instances": 0},
    missing_data_str="-",
    target_format="text",
    # exclude_methods=["RTS"],
)
styler
# Out:
# <style type="text/css">
# #T_26c2a_row0_col0, #T_26c2a_row0_col4, #T_26c2a_row1_col0, #T_26c2a_row1_col4, #T_26c2a_row11_col0, #T_26c2a_row11_col4, #T_26c2a_row12_col0, #T_26c2a_row12_col4, #T_26c2a_row22_col0, #T_26c2a_row22_col1, #T_26c2a_row22_col4, #T_26c2a_row22_col5, #T_26c2a_row23_col0, #T_26c2a_row23_col1, #T_26c2a_row23_col4, #T_26c2a_row23_col5, #T_26c2a_row24_col0, #T_26c2a_row24_col1, #T_26c2a_row24_col4, #T_26c2a_row24_col5, #T_26c2a_row25_col0, #T_26c2a_row25_col1, #T_26c2a_row25_col4, #T_26c2a_row25_col5, #T_26c2a_row26_col0, #T_26c2a_row26_col1, #T_26c2a_row26_col4, #T_26c2a_row26_col5, #T_26c2a_row27_col0, #T_26c2a_row27_col1, #T_26c2a_row27_col4, #T_26c2a_row27_col5, #T_26c2a_row28_col0, #T_26c2a_row28_col1, #T_26c2a_row28_col4, #T_26c2a_row28_col5, #T_26c2a_row29_col0, #T_26c2a_row29_col1, #T_26c2a_row29_col4, #T_26c2a_row29_col5, #T_26c2a_row30_col0, #T_26c2a_row30_col1, #T_26c2a_row30_col4, #T_26c2a_row30_col5, #T_26c2a_row31_col0, #T_26c2a_row31_col1, #T_26c2a_row31_col4, #T_26c2a_row31_col5, #T_26c2a_row32_col0, #T_26c2a_row32_col1, #T_26c2a_row32_col4, #T_26c2a_row32_col5, #T_26c2a_row33_col1, #T_26c2a_row33_col5, #T_26c2a_row34_col1, #T_26c2a_row34_col5, #T_26c2a_row35_col1, #T_26c2a_row35_col5, #T_26c2a_row36_col1, #T_26c2a_row36_col5, #T_26c2a_row37_col1, #T_26c2a_row37_col5, #T_26c2a_row38_col1, #T_26c2a_row38_col5, #T_26c2a_row39_col1, #T_26c2a_row39_col5, #T_26c2a_row40_col1, #T_26c2a_row40_col5, #T_26c2a_row41_col1, #T_26c2a_row41_col5, #T_26c2a_row42_col1, #T_26c2a_row42_col5, #T_26c2a_row43_col1, #T_26c2a_row43_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: white;
#   color: black;
# }
# #T_26c2a_row0_col1 {
#   background-color: #760c71;
#   color: #f1f1f1;
# }
# #T_26c2a_row0_col2 {
#   background-color: #81127e;
#   color: #f1f1f1;
# }
# #T_26c2a_row0_col3 {
#   background-color: #520150;
#   color: #f1f1f1;
# }
# #T_26c2a_row0_col5, #T_26c2a_row1_col5, #T_26c2a_row4_col4, #T_26c2a_row4_col5, #T_26c2a_row4_col6, #T_26c2a_row5_col4, #T_26c2a_row5_col5, #T_26c2a_row6_col4, #T_26c2a_row6_col5, #T_26c2a_row6_col6, #T_26c2a_row11_col5, #T_26c2a_row11_col6, #T_26c2a_row12_col5, #T_26c2a_row12_col6, #T_26c2a_row15_col4, #T_26c2a_row15_col5, #T_26c2a_row15_col6, #T_26c2a_row16_col4, #T_26c2a_row16_col5, #T_26c2a_row16_col6, #T_26c2a_row17_col4, #T_26c2a_row17_col5, #T_26c2a_row17_col6, #T_26c2a_row18_col6, #T_26c2a_row22_col6, #T_26c2a_row23_col6, #T_26c2a_row33_col7, #T_26c2a_row34_col7, #T_26c2a_row37_col4, #T_26c2a_row37_col6, #T_26c2a_row38_col4, #T_26c2a_row38_col6, #T_26c2a_row39_col4, #T_26c2a_row39_col6 {
#   background-color: #feebe7;
#   color: #000000;
# }
# #T_26c2a_row0_col6, #T_26c2a_row1_col6, #T_26c2a_row2_col4, #T_26c2a_row2_col5, #T_26c2a_row3_col4, #T_26c2a_row3_col5, #T_26c2a_row7_col4, #T_26c2a_row7_col5, #T_26c2a_row8_col4, #T_26c2a_row8_col5, #T_26c2a_row9_col4, #T_26c2a_row9_col5, #T_26c2a_row10_col4, #T_26c2a_row10_col5, #T_26c2a_row13_col4, #T_26c2a_row14_col4, #T_26c2a_row18_col4, #T_26c2a_row19_col4, #T_26c2a_row19_col5, #T_26c2a_row20_col4, #T_26c2a_row20_col5, #T_26c2a_row21_col4, #T_26c2a_row21_col5 {
#   background-color: #fddcd8;
#   color: #000000;
# }
# #T_26c2a_row0_col7, #T_26c2a_row1_col7, #T_26c2a_row7_col7, #T_26c2a_row11_col7, #T_26c2a_row12_col7 {
#   background-color: #fee9e6;
#   color: #000000;
# }
# #T_26c2a_row1_col1, #T_26c2a_row7_col0 {
#   background-color: #82147f;
#   color: #f1f1f1;
# }
# #T_26c2a_row1_col2 {
#   background-color: #873696;
#   color: #f1f1f1;
# }
# #T_26c2a_row1_col3 {
#   background-color: #5d055a;
#   color: #f1f1f1;
# }
# #T_26c2a_row2_col0 {
#   background-color: #8c74b5;
#   color: #f1f1f1;
# }
# #T_26c2a_row2_col1, #T_26c2a_row5_col3, #T_26c2a_row7_col1 {
#   background-color: #894da3;
#   color: #f1f1f1;
# }
# #T_26c2a_row2_col2 {
#   background-color: #8b65ae;
#   color: #f1f1f1;
# }
# #T_26c2a_row2_col3, #T_26c2a_row4_col1, #T_26c2a_row5_col1 {
#   background-color: #8a5aa9;
#   color: #f1f1f1;
# }
# #T_26c2a_row2_col6, #T_26c2a_row3_col6, #T_26c2a_row8_col6, #T_26c2a_row9_col6, #T_26c2a_row10_col6 {
#   background-color: #f988ad;
#   color: #f1f1f1;
# }
# #T_26c2a_row2_col7, #T_26c2a_row3_col7, #T_26c2a_row8_col7, #T_26c2a_row9_col7, #T_26c2a_row10_col7 {
#   background-color: #fde1de;
#   color: #000000;
# }
# #T_26c2a_row3_col0 {
#   background-color: #710a6d;
#   color: #f1f1f1;
# }
# #T_26c2a_row3_col1, #T_26c2a_row7_col3 {
#   background-color: #842289;
#   color: #f1f1f1;
# }
# #T_26c2a_row3_col2 {
#   background-color: #740b70;
#   color: #f1f1f1;
# }
# #T_26c2a_row3_col3 {
#   background-color: #88419d;
#   color: #f1f1f1;
# }
# #T_26c2a_row4_col0, #T_26c2a_row7_col2 {
#   background-color: #730b6e;
#   color: #f1f1f1;
# }
# #T_26c2a_row4_col2 {
#   background-color: #5a0457;
#   color: #f1f1f1;
# }
# #T_26c2a_row4_col3 {
#   background-color: #863394;
#   color: #f1f1f1;
# }
# #T_26c2a_row4_col7, #T_26c2a_row5_col7, #T_26c2a_row6_col7, #T_26c2a_row15_col7, #T_26c2a_row16_col7, #T_26c2a_row17_col7, #T_26c2a_row30_col7, #T_26c2a_row31_col7, #T_26c2a_row32_col7, #T_26c2a_row37_col7, #T_26c2a_row38_col7, #T_26c2a_row39_col7 {
#   background-color: #feefeb;
#   color: #000000;
# }
# #T_26c2a_row5_col0 {
#   background-color: #831d85;
#   color: #f1f1f1;
# }
# #T_26c2a_row5_col2 {
#   background-color: #8c68af;
#   color: #f1f1f1;
# }
# #T_26c2a_row5_col6, #T_26c2a_row26_col6, #T_26c2a_row28_col6 {
#   background-color: #fdddda;
#   color: #000000;
# }
# #T_26c2a_row6_col0 {
#   background-color: #8c6eb3;
#   color: #f1f1f1;
# }
# #T_26c2a_row6_col1, #T_26c2a_row9_col0 {
#   background-color: #8c90c3;
#   color: #f1f1f1;
# }
# #T_26c2a_row6_col2 {
#   background-color: #832088;
#   color: #f1f1f1;
# }
# #T_26c2a_row6_col3 {
#   background-color: #abc5df;
#   color: #000000;
# }
# #T_26c2a_row7_col6 {
#   background-color: #fa9db4;
#   color: #000000;
# }
# #T_26c2a_row8_col0 {
#   background-color: #8b5eab;
#   color: #f1f1f1;
# }
# #T_26c2a_row8_col1, #T_26c2a_row8_col2 {
#   background-color: #88439e;
#   color: #f1f1f1;
# }
# #T_26c2a_row8_col3 {
#   background-color: #84278c;
#   color: #f1f1f1;
# }
# #T_26c2a_row9_col1 {
#   background-color: #8950a4;
#   color: #f1f1f1;
# }
# #T_26c2a_row9_col2 {
#   background-color: #8b64ad;
#   color: #f1f1f1;
# }
# #T_26c2a_row9_col3 {
#   background-color: #8a55a7;
#   color: #f1f1f1;
# }
# #T_26c2a_row10_col0 {
#   background-color: #c2d5e7;
#   color: #000000;
# }
# #T_26c2a_row10_col1 {
#   background-color: #8c76b7;
#   color: #f1f1f1;
# }
# #T_26c2a_row10_col2 {
#   background-color: #8c8dc2;
#   color: #f1f1f1;
# }
# #T_26c2a_row10_col3 {
#   background-color: #8c82bc;
#   color: #f1f1f1;
# }
# #T_26c2a_row11_col1 {
#   background-color: #fffbd0;
#   color: #000000;
# }
# #T_26c2a_row11_col2, #T_26c2a_row15_col0 {
#   background-color: #6e2706;
#   color: #f1f1f1;
# }
# #T_26c2a_row11_col3 {
#   background-color: #662506;
#   color: #f1f1f1;
# }
# #T_26c2a_row12_col1 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_26c2a_row12_col2 {
#   background-color: #702806;
#   color: #f1f1f1;
# }
# #T_26c2a_row12_col3 {
#   background-color: #712806;
#   color: #f1f1f1;
# }
# #T_26c2a_row13_col0 {
#   background-color: #ed7215;
#   color: #f1f1f1;
# }
# #T_26c2a_row13_col1 {
#   background-color: #f4821d;
#   color: #f1f1f1;
# }
# #T_26c2a_row13_col2, #T_26c2a_row20_col2 {
#   background-color: #b03f03;
#   color: #f1f1f1;
# }
# #T_26c2a_row13_col3 {
#   background-color: #a63a03;
#   color: #f1f1f1;
# }
# #T_26c2a_row13_col5, #T_26c2a_row14_col5, #T_26c2a_row18_col5 {
#   background-color: #fcc9c4;
#   color: #000000;
# }
# #T_26c2a_row13_col6, #T_26c2a_row14_col6, #T_26c2a_row19_col6, #T_26c2a_row20_col6, #T_26c2a_row21_col6 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_26c2a_row13_col7, #T_26c2a_row14_col7, #T_26c2a_row27_col6, #T_26c2a_row35_col6, #T_26c2a_row36_col6 {
#   background-color: #fcceca;
#   color: #000000;
# }
# #T_26c2a_row14_col0, #T_26c2a_row18_col0 {
#   background-color: #682506;
#   color: #f1f1f1;
# }
# #T_26c2a_row14_col1 {
#   background-color: #dc5e0b;
#   color: #f1f1f1;
# }
# #T_26c2a_row14_col2, #T_26c2a_row15_col2, #T_26c2a_row16_col0 {
#   background-color: #792b05;
#   color: #f1f1f1;
# }
# #T_26c2a_row14_col3 {
#   background-color: #8b3005;
#   color: #f1f1f1;
# }
# #T_26c2a_row15_col1 {
#   background-color: #feba46;
#   color: #000000;
# }
# #T_26c2a_row15_col3 {
#   background-c

# %% [markdown]
# ## Create and save tables for LaTeX
#
# Here we format tables into LaTeX files and save them into separate `.tex` files
# suitable for inclusion in a paper. Files are saved with the current date and
# time for tracking changes. These can be compiled into a preview of all tables
# with `pdflatex summary_tables.tex`

# %%
AggValue: TypeAlias = Literal["num_instances", "approximation_ratio", "energy"]
values_to_plot: list[
    tuple[AggValue | Literal["both"], AggValue | list[AggValue], str, str]
] = [
    (
        "num_instances",
        "num_instances",
        "Number of Instances (num. nodes in brackets)",
        " Cells are colored based on the number of instances for the given configuration, with darker colors indicating more instances.",
    )
]
# Define values and captions for tables
if table.problem_class == "MC":
    values_to_plot.extend(
        [
            (
                "approximation_ratio",
                "approximation_ratio",
                r"Avg. Approx. Ratio $\pm$ standard deviation in percentage for MAXCUT",
                " Evaluation methods are shown in different colors, with darker colors indicating better approximation ratios.",
            ),
            (
                "both",
                ["approximation_ratio", "num_instances"],
                "Avg. Approx. Ratio and Number of Instances for Various Evaluation Methods for MAXCUT",
                " Evaluation methods are shown in different colors for approximation ratios."
                + " Darker colors indicating better approximation ratios or more instances."
                + " Approximation ratios are in percentage, with $\\pm$ their standard deviation."
                + " The range of graph sizes are shown in brackets, next to the number of instances.",
            ),
        ]
    )
elif table.problem_class == "MIS":
    values_to_plot.extend(
        [
            (
                "energy",
                "energy",
                r"Avg. Energy $\pm$ standard deviation for MIS",
                " Evaluation methods are shown in different colors, with darker colors indicating better energies."
                + " The minimum and maximum energies defining the range of colors are shared between MPS and PP."
                + " Note that energies include invalid solutions, which are penalized by the Hamiltonian.",
            ),
            (
                "both",
                ["energy", "num_instances"],
                "Avg. Energy and Number of Instances for Various Evaluation Methods for MIS",
                " Evaluation methods are shown in different colors for energies."
                + " Darker colors indicating better energies or more instances."
                + " The minimum and maximum energies defining the range of colors are shared between MPS and PP."
                + " Average energies are shown, with $\\pm$ their standard deviation."
                + " The range of graph sizes are shown in brackets, next to the number of instances.",
            ),
        ]
    )

# %%
## Create the CMAPs for each table.
TABLE_CMAPS_PER_EVALUATION = {
    "MPS (Aer)": "BuPu",
    "MPS (Quimb)": "YlOrBr",
    "PP": "YlGn",
    "SV": "PuBu",
}
table_cmap_num_instances = "Greens"
# The combined tables use different ranges for SV. MAXCUT has the same range for all evaluation
# methods, whereas SV has its own range for MIS data.
if table.problem_class == "MC":
    table_cmap_performance = TABLE_CMAPS_PER_EVALUATION
    table_cmap_combined = [
        {
            (str(k1), performance_metric): v
            for k1, v in TABLE_CMAPS_PER_EVALUATION.items()
        },
        {
            (str(k1), "num_instances"): "RdPu"
            for k1 in TABLE_CMAPS_PER_EVALUATION.keys()
        },
    ]
else:
    table_cmap_performance = [
        {"MPS (Aer)": "BuPu", "MPS (Quimb)": "YlOrBr", "PP": "YlGn"},
        {"SV": "PuBu"},
    ]
    table_cmap_combined = [
        {
            (str(k1), performance_metric): v
            for k1, v in TABLE_CMAPS_PER_EVALUATION.items()
            if k1 != "SV"
        },
        {
            (str(k1), performance_metric): v
            for k1, v in TABLE_CMAPS_PER_EVALUATION.items()
            if k1 == "SV"
        },
        {
            (str(k1), "num_instances"): "RdPu"
            for k1 in TABLE_CMAPS_PER_EVALUATION.keys()
        },
    ]

# %%
now = datetime.now(tz=timezone.utc)
generated_on_str = "% Generated on {now:%Y-%m-%d} at {now:%H:%M:%S} UTC\n".format(
    now=now
)
# Open a summary list_of_tables file for previewing all tables.
with open("list_of_tables_{}.tex".format(table.problem_class), "w") as f:
    # Write date and time to list_of_tables
    f.write(generated_on_str)

    # Iterate over all depths, sorted so they're included in increasing order in
    # list_of_tables
    for depth in sorted(int(x) for x in table.to_dataframe()["depth"].unique()):
        # Write a section title.
        _ = f.write("\n\\section{{Tables for depth $P={}$}}\n".format(depth))
        for filename_suffix, values, value_label, additional_caption in values_to_plot:
            # This is the filename for this table.
            _latex_filename = "table_{problem_class}_p{depth:02}_{suffix}.tex".format(
                problem_class=table.problem_class,
                depth=int(depth),
                suffix=filename_suffix,
            )
            if REFERENCE_METHODS_10 is not None and depth == 10:
                sub_table = table.only_common_instances(
                    REFERENCE_METHODS_10, per_depth=True
                )
            else:
                sub_table = table
            # Get the styler
            _, styler, _ = formatted_styler_for(
                sub_table,
                depths=depth,
                # Select the number of nodes for MIS, only.
                agg_values=values,
                with_fancy_values=True,
                cmap=(  # pyright: ignore[reportArgumentType]
                    table_cmap_num_instances
                    if values == "num_instances"
                    else table_cmap_performance
                )
                if isinstance(values, str)
                else table_cmap_combined,
                precision={performance_metric: 1, "num_instances": 0},
                missing_data_str="-",
                target_format="latex",
                show_empty_rows=True,
            )

            # Save table to separate LaTeX file
            with open(_latex_filename, "w") as f_table:
                _ = f_table.write(generated_on_str)
                _ = f_table.write(
                    "% Data is {value_label} for depth P={depth}.\n".format(
                        value_label=value_label, depth=depth
                    )
                )
                f_table.write(
                    convert_evaluation_to_multicolumn_latex(
                        styler.to_latex(
                            # f_table,
                            convert_css=True,
                            hrules=True,
                            clines="skip-last;data",
                        ),
                        num_metrics=len(values) if isinstance(values, list) else 1,
                    )
                )
            _ = f.write(
                r"""
\begin{{table}}[H]
    \centering
    \input{{{filename}}}
    \caption{{\textbf{{{value_label} for $P={depth}$.}} Graph types are Erdos Renyi (ER), Heavy-Hex (HH), Line-to-Full (LB), and Random Regular (RR).{additional_caption}}}
\end{{table}}
""".format(
                    filename=_latex_filename,
                    depth=depth,
                    value_label=value_label,
                    additional_caption=additional_caption,
                )
            )
            _ = f.write(r"\clearpage")
        # _ = f.write(r"\clearpage")

# %% [markdown]
# ## Compiling and previewing all tables
#
# Tables are written to `table_p<depth>_<metric>.tex` where `<depth>` is the QAOA
# depth and `<metric>` is either `approximation_ratio` or `num_instances`. These
# LaTeX files contain the `tabular` environments to include the given tables.
# Numerical values are formatted with siunitx for easier precision and uncertainty
# handling. All of these tables are then included in `tables.tex` as a list of
# sections, one per depth. `summary_tables.tex` is an example LaTeX document that
# (i) has an appropriate preamble for rendering the tables and (ii) shows how to
# include them in a larger document.
#
# To compile the _sample document_ `summary_tables.tex`, run the following command
# after generating the LaTeX files:
#
# ```bash
# latexmk -pdf summary_tables.tex
# ```

# %%
# !latexmk -pdf summary_tables.tex
# Out:
# Rc files read (in order):
#   NONE
# Latexmk: This is Latexmk, John Collins, 9 March 2026. Version 4.88.
# Latexmk: applying rule 'pdflatex'...
# Rule 'pdflatex':  Reasons for rerun
# Changed files or newly in use/created:
#   list_of_tables_MC.tex
#   table_MC_p01_approximation_ratio.tex
#   table_MC_p01_both.tex
#   table_MC_p01_num_instances.tex
#   table_MC_p02_approximation_ratio.tex
#   table_MC_p02_both.tex
#   table_MC_p02_num_instances.tex
#   table_MC_p03_approximation_ratio.tex
#   table_MC_p03_both.tex
#   table_MC_p03_num_instances.tex
#   table_MC_p04_approximation_ratio.tex
#   table_MC_p04_both.tex
#   table_MC_p04_num_instances.tex
#   table_MC_p05_approximation_ratio.tex
#   table_MC_p05_both.tex
#   table_MC_p05_num_instances.tex
#   table_MC_p06_approximation_ratio.tex
#   table_MC_p06_both.tex
#   table_MC_p06_num_instances.tex
#   table_MC_p07_approximation_ratio.tex
#   table_MC_p07_both.tex
#   table_MC_p07_num_instances.tex
#   table_MC_p08_approximation_ratio.tex
#   table_MC_p08_both.tex
#   table_MC_p08_num_instances.tex
#   table_MC_p09_approximation_ratio.tex
#   table_MC_p09_both.tex
#   table_MC_p09_num_instances.tex
#   table_MC_p10_approximation_ratio.tex
#   table_MC_p10_both.tex
#   table_MC_p10_num_instances.tex
# Category 'changed_user':
#   list_of_tables_MC.tex
#   table_MC_p01_approximation_ratio.tex
#   table_MC_p01_both.tex
#   table_MC_p01_num_instances.tex
#   table_MC_p02_approximation_ratio.tex
#   table_MC_p02_both.tex
#   table_MC_p02_num_instances.tex
#   table_MC_p03_approximation_ratio.tex
#   table_MC_p03_both.tex
#   table_MC_p03_num_instances.tex
#   table_MC_p04_approximation_ratio.tex
#   table_MC_p04_both.tex
#   table_MC_p04_num_instances.tex
#   table_MC_p05_approximation_ratio.tex
#   table_MC_p05_both.tex
#   table_MC_p05_num_instances.tex
#   table_MC_p06_approximation_ratio.tex
#   table_MC_p06_both.tex
#   table_MC_p06_num_instances.tex
#   table_MC_p07_approximation_ratio.tex
#   table_MC_p07_both.tex
#   table_MC_p07_num_instances.tex
#   table_MC_p08_approximation_ratio.tex
#   table_MC_p08_both.tex
#   table_MC_p08_num_instances.tex
#   table_MC_p09_approximation_ratio.tex
#   table_MC_p09_both.tex
#   table_MC_p09_num_instances.tex
#   table_MC_p10_approximation_ratio.tex
#   table_MC_p10_both.tex
#   table_MC_p10_num_instances.tex
#
# ------------
# Run number 1 of rule 'pdflatex'
# ------------
# ------------
# Running 'pdflatex  -recorder  "summary_tables.tex"'
# ------------
# This is pdfTeX, Version 3.141592653-2.6-1.40.29 (TeX Live 2026) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./summary_tables.tex
# LaTeX2e <2025-11-01>
# L3 programming layer <2026-01-19>
# (/usr/local/texlive/2026/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2025/01/22 v1.4n Standard LaTeX document class
# (/usr/local/texlive/2026/texmf-dist/tex/latex/base/size10.clo))
# (/usr/local/texlive/2026/texmf-dist/tex/latex/booktabs/booktabs.sty)
# (/usr/local/texlive/2026/texmf-dist/tex/latex/xcolor/xcolor.sty
# (/usr/local/texlive/2026/texmf-dist/tex/latex/graphics-cfg/color.cfg)
# (/usr/local/texlive/2026/texmf-dist/tex/latex/graphics-def/pdftex.def)
# (/usr/local/texlive/2026/texmf-dist/tex/latex/graphics/mathcolor.ltx))
# (/usr/local/texlive/2026/texmf-dist/tex/latex/colortbl/colortbl.sty
# (/usr/local/texlive/2026/texmf-dist/tex/latex/tools/array.sty))
# (/usr/local/texlive/2026/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2026/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2026/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2026/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2026/texmf-dist/tex/latex/float/float.sty)
# (/usr/local/texlive/2026/texmf-dist/tex/latex/multirow/multirow.sty)
# (/usr/local/texlive/2026/texmf-dist/tex/latex/siunitx/siunitx.sty
# (/usr/local/texlive/2026/texmf-dist/tex/latex/translations/translations.sty
# (/usr/local/texlive/2026/texmf-dist/tex/latex/etoolbox/etoolbox.sty)
# (/usr/local/texlive/2026/texmf-dist/tex/generic/pdftexcmds/pdftexcmds.sty
# (/usr/local/texlive/2026/texmf-dist/tex/generic/infwarerr/infwarerr.sty)
# (/usr/local/texlive/2026/texmf-dist/tex/generic/ltxcmds/ltxcmds.sty)))
# (/usr/local/texlive/2026/texmf-dist/tex/latex/amsmath/amstext.sty
# (/usr/local/texlive/2026/texmf-dist/tex/latex/amsmath/amsgen.sty)))
# (/usr/local/texlive/2026/texmf-dist/tex/latex/l3backend/l3backend-pdftex.def)
# (./summary_tables.aux)
# (/usr/local/texlive/2026/texmf-dist/tex/context/base/mkii/supp-pdf.mkii
# [Loading MPS to PDF converter (version 2006.09.02).]
# )
# *geometry* driver: auto-detecting
# *geometry* detected driver: pdftex
#
# (/usr/local/texlive/2026/texmf-dist/tex/latex/translations/translations-basic-d
# ictionary-english.trsl) (./list_of_tables_MC.tex
# (./table_MC_p01_num_instances.tex) [1{/usr/local/texlive/2026/texmf-var/fonts/m
# ap/pdftex/updmap/pdftex.map}]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [2] (./table_MC_p01_approximation_ratio.tex) [3] (./table_MC_p01_both.tex)
# Overfull \hbox (69.64716pt too wide) in paragraph at lines 3--20
#  [][]
# [4]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [5] (./table_MC_p02_num_instances.tex) [6]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [7] (./table_MC_p02_approximation_ratio.tex) [8] (./table_MC_p02_both.tex)
# Overfull \hbox (74.64717pt too wide) in paragraph at lines 3--40
#  [][]
# [9]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [10] (./table_MC_p03_num_instances.tex) [11]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [12] (./table_MC_p03_approximation_ratio.tex) [13] (./table_MC_p03_both.tex)
# Overfull \hbox (74.64717pt too wide) in paragraph at lines 3--60
#  [][]
# [14]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [15] (./table_MC_p04_num_instances.tex) [16]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [17] (./table_MC_p04_approximation_ratio.tex) [18] (./table_MC_p04_both.tex)
# Overfull \hbox (84.6472pt too wide) in paragraph at lines 3--80
#  [][]
# [19]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [20] (./table_MC_p05_num_instances.tex) [21]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [22] (./table_MC_p05_approximation_ratio.tex) [23] (./table_MC_p05_both.tex)
# Overfull \hbox (89.64722pt too wide) in paragraph at lines 3--100
#  [][]
# [24]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [25] (./table_MC_p06_num_instances.tex) [26]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [27] (./table_MC_p06_approximation_ratio.tex) [28] (./table_MC_p06_both.tex)
# Overfull \hbox (89.64722pt too wide) in paragraph at lines 3--120
#  [][]
# [29]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [30] (./table_MC_p07_num_instances.tex) [31]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [32] (./table_MC_p07_approximation_ratio.tex) [33] (./table_MC_p07_both.tex)
# Overfull \hbox (84.6472pt too wide) in paragraph at lines 3--140
#  [][]
# [34]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [35] (./table_MC_p08_num_instances.tex) [36]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [37] (./table_MC_p08_approximation_ratio.tex) [38] (./table_MC_p08_both.tex)
# Overfull \hbox (89.64722pt too wide) in paragraph at lines 3--160
#  [][]
# [39]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [40] (./table_MC_p09_num_instances.tex) [41]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [42] (./table_MC_p09_approximation_ratio.tex) [43] (./table_MC_p09_both.tex)
# Overfull \hbox (89.64722pt too wide) in paragraph at lines 3--180
#  [][]
# [44]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [45] (./table_MC_p10_num_instances.tex) [46]
# Overfull \vbox (17.2936pt too high) has occurred while \output is active
# [47] (./table_MC_p10_approximation_ratio.tex) [48] (./table_MC_p10_both.tex)
# Overfull \hbox (84.6472pt too wide) in paragraph at lines 3--200
#  [][]
# [49]
# Overfull \vbox (24.09085pt too high) has occurred while \output is active
# [50]) (./list_of_tables_MIS.tex (./table_MIS_p01_num_instances.tex) [51]
# (./table_MIS_p01_energy.tex) [52] (./table_MIS_p01_both.tex)
# Overfull \hbox (89.64722pt too wide) in paragraph at lines 3--20
#  [][]
# [53] (./table_MIS_p02_num_instances.tex) [54] (./table_MIS_p02_energy.tex)
# [55] (./table_MIS_p02_both.tex)
# Overfull \hbox (104.64726pt too wide) in paragraph at lines 3--40
#  [][]
# [56] (./table_MIS_p03_num_instances.tex) [57] (./table_MIS_p03_energy.tex)
# [58] (./table_MIS_p03_both.tex)
# Overfull \hbox (109.64728pt too wide) in paragraph at lines 3--60
#  [][]
# [59] (./table_MIS_p04_num_instances.tex) [60] (./table_MIS_p04_energy.tex)
# [61] (./table_MIS_p04_both.tex)
# Overfull \hbox (109.64728pt too wide) in paragraph at lines 3--80
#  [][]
# [62] (./table_MIS_p05_num_instances.tex) [63] (./table_MIS_p05_energy.tex)
# [64] (./table_MIS_p05_both.tex)
# Overfull \hbox (109.64728pt too wide) in paragraph at lines 3--100
#  [][]
# [65] (./table_MIS_p06_num_instances.tex) [66] (./table_MIS_p06_energy.tex)
# [67] (./table_MIS_p06_both.tex)
# Overfull \hbox (109.64728pt too wide) in paragraph at lines 3--120
#  [][]
# [68] (./table_MIS_p07_num_instances.tex) [69] (./table_MIS_p07_energy.tex)
# [70] (./table_MIS_p07_both.tex)
# Overfull \hbox (79.64719pt too wide) in paragraph at lines 3--140
#  [][]
# [71] (./table_MIS_p08_num_instances.tex) [72] (./table_MIS_p08_energy.tex)
# [73] (./table_MIS_p08_both.tex)
# Overfull \hbox (79.64719pt too wide) in paragraph at lines 3--160
#  [][]
# [74] (./table_MIS_p09_num_instances.tex) [75] (./table_MIS_p09_energy.tex)
# [76] (./table_MIS_p09_both.tex)
# Overfull \hbox (79.64719pt too wide) in paragraph at lines 3--180
#  [][]
# [77] (./table_MIS_p10_num_instances.tex) [78] (./table_MIS_p10_energy.tex)
# [79] (./table_MIS_p10_both.tex)
# Overfull \hbox (79.64719pt too wide) in paragraph at lines 3--200
#  [][]
# [80]) (./summary_tables.aux) )
# (see the transcript file for additional information)</usr/local/texlive/2026/te
# xmf-dist/fonts/type1/public/amsfonts/cm/cmbx10.pfb></usr/local/texlive/2026/tex
# mf-dist/fonts/type1/public/amsfonts/cm/cmbx12.pfb></usr/local/texlive/2026/texm
# f-dist/fonts/type1/public/amsfonts/cm/cmmi10.pfb></usr/local/texlive/2026/texmf
# -dist/fonts/type1/public/amsfonts/cm/cmmi12.pfb></usr/local/texlive/2026/texmf-
# dist/fonts/type1/public/amsfonts/cm/cmmi7.pfb></usr/local/texlive/2026/texmf-di
# st/fonts/type1/public/amsfonts/cm/cmr10.pfb></usr/local/texlive/2026/texmf-dist
# /fonts/type1/public/amsfonts/cm/cmr12.pfb></usr/local/texlive/2026/texmf-dist/f
# onts/type1/public/amsfonts/cm/cmr17.pfb></usr/local/texlive/2026/texmf-dist/fon
# ts/type1/public/amsfonts/cm/cmsy10.pfb></usr/local/texlive/2026/texmf-dist/font
# s/type1/public/amsfonts/cm/cmsy7.pfb></usr/local/texlive/2026/texmf-dist/fonts/
# type1/public/amsfonts/cm/cmtt12.pfb>
# Output written on summary_tables.pdf (80 pages, 444912 bytes).
# Transcript written on summary_tables.log.
# Latexmk: Getting log file 'summary_tables.log'
# Latexmk: Examining 'summary_tables.fls'
# Latexmk: Examining 'summary_tables.log'
# Latexmk: Log file says output to 'summary_tables.pdf'
# Latexmk: All targets (summary_tables.pdf) are up-to-date

# %% [markdown]
# # Missing Files

# %% [markdown]
# ## Setup

# %%
from IPython.display import display

# %%
if table.problem_class == "MC":
    missing_depth = 10
elif table.problem_class == "MIS":
    missing_depth = 6
else:
    raise ValueError(
        f"Problem class {table.problem_class!r} not supported for missing-config generation."
    )

# %% [markdown]
# ## Identify all methods we want to include in the table

# %%
# These are the methods we would like to include in our tables. Some are
# 'virtual' _no_opt methods as no method JSON file exists, but we extract the
# data from an intermediate run of an _opt-method run.
def _filter_configs_for_problem_class(
    configs: list[MethodConfigJSON], problem_class: str
) -> list[MethodConfigJSON]:
    """Filter target instances based on the problem class.

    We remove Fixed Angle results for MIS as we don't want to hardcode a degree.
    MAXCUT tables are fine, as we have varied number of runs per graph type and
    method.
    """
    if problem_class == "MIS":
        # Remove Fixed Angles
        return [m for m in configs if not m.startswith("FA_")]
    return configs


target_methods: dict[
    EvaluationType, list[MethodConfigJSON] | dict[bool, list[MethodConfigJSON]]
] = {
    "MPS": {
        True: _filter_configs_for_problem_class(
            cast(
                list[MethodConfigJSON],
                [
                    "FA_MPSAer_no_opt.json",
                    "FA_MPSAer_opt.json",
                    "F_MPSAer.json",
                    "I_MPSAer.json",
                    "LR_MPSAer_angle_opt.json",
                    "LR_MPSAer_opt.json",
                    "LR_MPSAer_no_opt.json",
                    "RTS_MPSAer.json",
                    "TQA_MPSAer_no_opt.json",
                    "TQA_MPSAer_opt.json",
                ],
            ),
            table.problem_class,
        ),
        False: _filter_configs_for_problem_class(
            cast(
                list[MethodConfigJSON],
                [
                    "FA_MPS_no_opt.json",
                    "FA_MPS_opt.json",
                    "F_MPS.json",
                    "I_MPS.json",
                    "LR_MPS_angle_opt.json",
                    "LR_MPS_opt.json",
                    "LR_MPS_no_opt.json",
                    "RTS_MPS.json",
                    "TQA_MPS_no_opt.json",
                    "TQA_MPS_opt.json",
                ],
            ),
            table.problem_class,
        ),
    },
    "PP": _filter_configs_for_problem_class(
        cast(
            list[MethodConfigJSON],
            [
                "FA_PP_no_opt.json",
                "FA_PP_opt.json",
                "F_PP.json",
                "I_PP.json",
                "LR_PP_angle_opt.json",
                "LR_PP_opt.json",
                "LR_PP_no_opt.json",
                # We don't want Parameter Transfer at all.
                # "PT_PP_AAAM.json",
                "RTS_PP.json",
                "TQA_PP_no_opt.json",
                "TQA_PP_opt.json",
            ],
        ),
        table.problem_class,
    ),
    "SV": _filter_configs_for_problem_class(
        cast(
            list[MethodConfigJSON],
            [
                "FA_SV_no_opt.json",
                "FA_SV_opt.json",
                "F_SV.json",
                "I_SV.json",
                "LR_SV_angle_opt.json",
                "LR_SV_opt.json",
                "LR_SV_no_opt.json",
                "TQA_SV_no_opt.json",
                "TQA_SV_opt.json",
                "TS_SV.json",
            ],
        ),
        table.problem_class,
    ),
}

all_methods: list[MethodConfigJSON] = list(
    set(
        method
        for methods in target_methods.values()
        for method in (
            methods
            if isinstance(methods, list)
            else [m for sublist in methods.values() for m in sublist]
        )
    )
)

# %% [markdown]
# ### Create Row Index for Pivot Tables

# %%
# Create multi-index of target evaluation and method labels.
row_index = pd.MultiIndex.from_tuples(
    [
        (
            evaluation_label,
            method_label,
        )
        for evaluation_label, method_label in product(
            ["MPS (Aer)", "MPS (Quimb)", "PP", "SV"],
            sorted(
                set(
                    [
                        utils.labels.trainer_config_to_method_label(m)
                        for m in all_methods
                    ]
                ),
                key=utils.labels.method_sort_key,
            ),
        )
    ],
)

# %% [markdown]
# ## Filter table for reference methods (MAXCUT only)

# %%
# Filter for common instances for MAXCUT P=10 table
if table.problem_class == "MC":
    assert REFERENCE_METHODS_10 is not None
    # We filter by reference methods as table was not filtered by common
    # instances. Only sub_table during LaTeX table generation is filtered, and
    # only for P=10.
    missing_table = table.only_common_instances(
        REFERENCE_METHODS_10,
        per_depth=True,
    )
elif table.problem_class == "MIS":
    # We don't filter by num_nodes as we already did that in the table creation.
    missing_table = table
else:
    raise ValueError(f"Unrecognised problem class {table.problem_class!r}.")

# %% [markdown]
# ## Pivot Table of Existing Runs

# %%
# 1. Show the number of runs
pivot, _, _ = formatted_styler_for(
    missing_table,
    agg_values="num_instances",
    depths=missing_depth,
    show_empty_rows=True,
)
# We need to reprocess the values to floats as formatted_styler_for converts
# them to strings.
pivot = pivot.map(lambda x: float(x))
pivot = pivot.reindex(index=row_index)
styler: Styler = pivot.style.format(na_rep="-", precision=0)  # pyright: ignore[reportAssignmentType]
styler = styler.background_gradient("Greens", axis=None).highlight_null("red")
display(styler)
# Out:
# <style type="text/css">
# #T_e007d_row0_col0, #T_e007d_row0_col1, #T_e007d_row0_col2, #T_e007d_row0_col3, #T_e007d_row1_col0, #T_e007d_row1_col1, #T_e007d_row1_col2, #T_e007d_row1_col3, #T_e007d_row2_col0, #T_e007d_row3_col0, #T_e007d_row5_col0, #T_e007d_row5_col1, #T_e007d_row5_col2, #T_e007d_row5_col3, #T_e007d_row6_col0, #T_e007d_row6_col1, #T_e007d_row6_col2, #T_e007d_row6_col3, #T_e007d_row9_col0, #T_e007d_row9_col1, #T_e007d_row9_col2, #T_e007d_row9_col3, #T_e007d_row10_col0, #T_e007d_row10_col1, #T_e007d_row10_col2, #T_e007d_row10_col3, #T_e007d_row13_col0, #T_e007d_row13_col1, #T_e007d_row13_col2, #T_e007d_row13_col3, #T_e007d_row14_col0, #T_e007d_row14_col1, #T_e007d_row14_col2, #T_e007d_row14_col3, #T_e007d_row15_col0, #T_e007d_row15_col1, #T_e007d_row15_col2, #T_e007d_row15_col3, #T_e007d_row16_col0, #T_e007d_row16_col1, #T_e007d_row17_col0, #T_e007d_row17_col1, #T_e007d_row19_col0, #T_e007d_row19_col1, #T_e007d_row19_col2, #T_e007d_row19_col3, #T_e007d_row20_col0, #T_e007d_row20_col1, #T_e007d_row20_col2, #T_e007d_row20_col3, #T_e007d_row23_col0, #T_e007d_row23_col1, #T_e007d_row23_col2, #T_e007d_row23_col3, #T_e007d_row24_col0, #T_e007d_row24_col1, #T_e007d_row24_col2, #T_e007d_row24_col3, #T_e007d_row27_col0, #T_e007d_row27_col1, #T_e007d_row27_col2, #T_e007d_row27_col3, #T_e007d_row28_col0, #T_e007d_row28_col1, #T_e007d_row28_col2, #T_e007d_row28_col3, #T_e007d_row29_col0, #T_e007d_row29_col1, #T_e007d_row29_col2, #T_e007d_row29_col3, #T_e007d_row30_col0, #T_e007d_row31_col0, #T_e007d_row33_col0, #T_e007d_row33_col1, #T_e007d_row33_col2, #T_e007d_row33_col3, #T_e007d_row34_col0, #T_e007d_row34_col1, #T_e007d_row34_col2, #T_e007d_row34_col3, #T_e007d_row37_col0, #T_e007d_row37_col1, #T_e007d_row37_col2, #T_e007d_row37_col3, #T_e007d_row38_col0, #T_e007d_row38_col1, #T_e007d_row38_col2, #T_e007d_row38_col3, #T_e007d_row41_col0, #T_e007d_row41_col1, #T_e007d_row41_col2, #T_e007d_row41_col3, #T_e007d_row42_col0, #T_e007d_row42_col1, #T_e007d_row42_col2, #T_e007d_row42_col3, #T_e007d_row43_col0, #T_e007d_row43_col1, #T_e007d_row43_col2, #T_e007d_row43_col3, #T_e007d_row44_col1, #T_e007d_row45_col1, #T_e007d_row47_col0, #T_e007d_row47_col1, #T_e007d_row47_col2, #T_e007d_row47_col3, #T_e007d_row48_col0, #T_e007d_row48_col1, #T_e007d_row48_col2, #T_e007d_row48_col3, #T_e007d_row51_col0, #T_e007d_row51_col1, #T_e007d_row51_col2, #T_e007d_row51_col3, #T_e007d_row52_col0, #T_e007d_row52_col1, #T_e007d_row52_col2, #T_e007d_row52_col3, #T_e007d_row55_col0, #T_e007d_row55_col1, #T_e007d_row55_col2, #T_e007d_row55_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: red;
# }
# #T_e007d_row2_col1, #T_e007d_row3_col1, #T_e007d_row4_col0, #T_e007d_row4_col1, #T_e007d_row7_col0, #T_e007d_row7_col1, #T_e007d_row8_col0, #T_e007d_row8_col1, #T_e007d_row11_col0, #T_e007d_row11_col1, #T_e007d_row12_col0, #T_e007d_row12_col1, #T_e007d_row18_col0, #T_e007d_row21_col0, #T_e007d_row22_col0, #T_e007d_row25_col0, #T_e007d_row26_col0, #T_e007d_row32_col0, #T_e007d_row35_col0, #T_e007d_row36_col0, #T_e007d_row39_col0, #T_e007d_row40_col0, #T_e007d_row46_col1, #T_e007d_row49_col1, #T_e007d_row50_col1, #T_e007d_row53_col1, #T_e007d_row54_col1 {
#   background-color: #e8f6e4;
#   color: #000000;
# }
# #T_e007d_row2_col2, #T_e007d_row3_col2 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_e007d_row2_col3, #T_e007d_row3_col3, #T_e007d_row4_col3, #T_e007d_row7_col3, #T_e007d_row8_col3, #T_e007d_row11_col3, #T_e007d_row12_col3 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_e007d_row4_col2, #T_e007d_row7_col2, #T_e007d_row8_col2, #T_e007d_row11_col2, #T_e007d_row12_col2 {
#   background-color: #c2e7bb;
#   color: #000000;
# }
# #T_e007d_row16_col2, #T_e007d_row17_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_e007d_row16_col3, #T_e007d_row17_col3, #T_e007d_row18_col3, #T_e007d_row21_col3, #T_e007d_row22_col3, #T_e007d_row25_col3, #T_e007d_row26_col3, #T_e007d_row30_col3, #T_e007d_row31_col3 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_e007d_row18_col1, #T_e007d_row21_col1, #T_e007d_row22_col1, #T_e007d_row25_col1, #T_e007d_row26_col1 {
#   background-color: #dcf2d7;
#   color: #000000;
# }
# #T_e007d_row18_col2, #T_e007d_row21_col2, #T_e007d_row22_col2, #T_e007d_row25_col2, #T_e007d_row26_col2, #T_e007d_row30_col2, #T_e007d_row31_col2 {
#   background-color: #f0f9ed;
#   color: #000000;
# }
# #T_e007d_row30_col1, #T_e007d_row31_col1, #T_e007d_row32_col1, #T_e007d_row35_col1, #T_e007d_row36_col1, #T_e007d_row39_col1, #T_e007d_row40_col1 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_e007d_row32_col2, #T_e007d_row35_col2, #T_e007d_row36_col2, #T_e007d_row39_col2, #T_e007d_row40_col2 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_e007d_row32_col3, #T_e007d_row35_col3, #T_e007d_row36_col3, #T_e007d_row39_col3, #T_e007d_row40_col3 {
#   background-color: #eaf7e6;
#   color: #000000;
# }
# #T_e007d_row44_col0, #T_e007d_row45_col0 {
#   background-color: #ebf7e7;
#   color: #000000;
# }
# #T_e007d_row44_col2, #T_e007d_row45_col2 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_e007d_row44_col3, #T_e007d_row45_col3 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_e007d_row46_col0, #T_e007d_row49_col0, #T_e007d_row50_col0, #T_e007d_row53_col0, #T_e007d_row54_col0 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_e007d_row46_col2, #T_e007d_row49_col2, #T_e007d_row50_col2, #T_e007d_row53_col2, #T_e007d_row54_col2 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_e007d_row46_col3, #T_e007d_row49_col3, #T_e007d_row50_col3, #T_e007d_row53_col3, #T_e007d_row54_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e007d">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >graph_type</th>
#       <th id="T_e007d_level0_col0" class="col_heading level0 col0" >ER</th>
#       <th id="T_e007d_level0_col1" class="col_heading level0 col1" >HH</th>
#       <th id="T_e007d_level0_col2" class="col_heading level0 col2" >LB</th>
#       <th id="T_e007d_level0_col3" class="col_heading level0 col3" >RR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e007d_level0_row0" class="row_heading level0 row0" rowspan="14">MPS (Aer)</th>
#       <th id="T_e007d_level1_row0" class="row_heading level1 row0" >F.json</th>
#       <td id="T_e007d_row0_col0" class="data row0 col0" >-</td>
#       <td id="T_e007d_row0_col1" class="data row0 col1" >-</td>
#       <td id="T_e007d_row0_col2" class="data row0 col2" >-</td>
#       <td id="T_e007d_row0_col3" class="data row0 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_e007d_level1_row1" class="row_heading level1 row1" >FAer.json</th>
#       <td id="T_e007d_row1_col0" class="data row1 col0" >-</td>
#       <td id="T_e007d_row1_col1" class="data row1 col1" >-</td>
#       <td id="T_e007d_row1_col2" class="data row1 col2" >-</td>
#       <td id="T_e007d_row1_col3" class="data row1 col3" >-</td>
#     </tr>
#     <tr>
#       <th id="T_e007d_level1_row2" class="row_heading level1 row2" >Fixed Angles*</th>
#       <td id="T_e007d_row2_col0" class="data row2 col0" >-</td>
#       <td id="T_e007d_row2_col1" class="data row2 col1" >20</td>
#       <td id="T_e007d_row2_col2" class="data row2 col2" >14</td>
#       <td id="T_e007d_row2_col3" class="data row2 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_e007d_level1_row3" class="row_heading level1 row3" >Fixed Angles†</th>
#       <td id="T_e007d_row3_col0" class="data row3 col0" >-</td>
#       <td id="T_e007d_row3_col1" class="data row3 col1" >20</td>
#       <td id="T_e007d_row3_col2" class="data row3 col2" >14</td>
#       <td id="T_e007d_row3_col3" class="data row3 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_e007d_level1_row4" class="row_heading level1 row4" >Interp.*</th>
#       <td id="T_e007d_row4_col0" class="data row4 col0" >20</td>
#       <td id="T_e007d_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_e007d_row4_col2" class="data row4 col2" >50</td>
#       <td id="T_e007d_row4_col3" class="data row4 col3" >11</td>
#     </tr>
#     <tr>

# %% [markdown]
# ## Get Missing Instances

# %% [markdown]
# ### Create Mapping of Target Instances

# %%
# Helper functions for saving and loading the target instances to a JSON file.
def __sort_graph_key(graph_key: GraphKey) -> str:
    # The first 4 characters of graph_key are the graph indexes. We move this to
    # the end of the sorting key so we always group (1) the same sized graphs
    # together and (2) graphs of the same type together.
    if len(graph_key) < 4:
        # Catch-all in-case we don't have enough characters. This should never
        # be the case, but we do it anyway.
        return graph_key
    return graph_key[3:] + graph_key[:]


def save_target_instances_json(
    obj: Mapping[EvaluationType, set[GraphKey] | Mapping[bool, set[GraphKey]]], path
):
    output = {}
    for key1, val1 in obj.items():
        if isinstance(val1, set):
            output[key1] = list(sorted(val1, key=__sort_graph_key))
        else:
            output[key1] = {}
            for key2, val2 in val1.items():
                if isinstance(val2, set):
                    output[key1][key2] = list(sorted(val2, key=__sort_graph_key))
                else:
                    output[key1][key2] = val2
    with open(path, "w") as f:
        json.dump(output, f, indent=2)


def load_target_instances_json(
    path,
) -> dict[EvaluationType, set[GraphKey] | dict[bool, set[GraphKey]]]:
    with open(path, "r") as f:
        data = json.load(f)
    output: dict[EvaluationType, set[GraphKey] | dict[bool, set[GraphKey]]] = {}
    key1: EvaluationType
    for key1, val1 in data.items():
        assert isinstance(key1, str)
        if isinstance(val1, list):
            output[key1] = set(val1)
        else:
            output[key1] = {}
            for key2, val2 in val1.items():
                _bool_key2 = key2 == "true"
                if isinstance(val2, list):
                    output[key1][_bool_key2] = set(val2)  # pyright: ignore[reportIndexIssue]
                else:
                    output[key1][_bool_key2] = val2  # pyright: ignore[reportIndexIssue]
    return output

# %%
target_instances_for_missing: dict[
    EvaluationType, set[GraphKey] | dict[bool, set[GraphKey]]
] = {}
if missing_table.problem_class == "MC":
    # ========================================
    # Determine the target instances for MAXCUT
    # ========================================
    #
    # This is done in two possible ways:
    # 1. Using `{problem_class}_target_instances.json`.
    # 2. By determining all instances we have in the data and populating the
    #    table with them.
    #
    # Depending on what you are doing, you will choose one of these. Note that
    # we do not use these methods for MIS. Instead we programmatically define
    # those earlier in the notebook.
    #
    # BY DEFAULT YOU SHOULD USE OPTION 1. THIS ENSURES YOU ARE CHECKING THE
    # CORRECT INSTANCES.

    # OPTION 1
    # ========
    # target_instances_for_missing = load_target_instances_json(
    #     f"{table.problem_class}_target_instances.json"
    # )

    # OPTION 2
    # ========
    target_instances_for_missing = {}
    for _inst, _inst_data in missing_table.data.items():
        for trainer_config, trainer_data in _inst_data.items():
            if missing_depth not in trainer_data:
                continue
            evaluation = utils.labels.trainer_config_to_evaluation(trainer_config)
            with_aer = utils.labels.method_uses_aer(trainer_config)
            if evaluation not in target_instances_for_missing:
                if evaluation == "MPS":
                    target_instances_for_missing[evaluation] = {
                        True: set(),
                        False: set(),
                    }
                else:
                    target_instances_for_missing[evaluation] = set()
            if evaluation == "MPS":
                target_instances_for_missing[evaluation][with_aer].add(_inst)  # pyright: ignore[reportIndexIssue]
            else:
                target_instances_for_missing[evaluation].add(_inst)  # pyright: ignore[reportAttributeAccessIssue]

elif missing_table.problem_class == "MIS":
    assert TARGET_INSTANCES is not None
    target_instances_for_missing = TARGET_INSTANCES
else:
    raise ValueError(
        f"Cannot compute target instances for problem class {missing_table.problem_class!r}."
    )

# %% [markdown]
# ### Load Failed Runs

# %%
failed_runs_filename = Path(f"failed_runs_{table.problem_class}.json")
failed_runs: dict[GraphKey, dict[MethodConfigJSON, dict[Depth, str]]]
if failed_runs_filename.exists():
    failed_runs = missing_table.load_failed_configs_from_json(failed_runs_filename)
else:
    failed_runs = defaultdict(lambda: defaultdict(dict))

# %% [markdown]
# ### Compute Missing Instances Dataframe

# %%
missing: dict[
    EvaluationType | tuple[Literal["MPS"], bool],
    dict[MethodConfigJSON, dict[Depth, set[GraphKey]]],
] = missing_table.get_missing_configs(
    target_instances=target_instances_for_missing,
    target_depths=[missing_depth],
    target_methods=target_methods,
    # failed_configs=None,
    failed_configs=failed_runs,
    # We do not return derived configs as we can extract them from `missing`.
    with_derived_configs=False,
)

missing_records = []
for _eval_type, _eval_data in missing.items():
    if _eval_type in ["SV", "PP"]:
        _evaluation = _eval_type
        _with_aer = None
    elif _eval_type[0] == "MPS":
        _evaluation = _eval_type[0]
        _with_aer = _eval_type[1]
    else:
        raise ValueError(f"Evaluation {_eval_type!r} not recognized.")
    for _trainer_config, _method_data in _eval_data.items():
        for _depth, _instances in _method_data.items():
            assert _depth == missing_depth
            missing_records.extend(
                [
                    {
                        "instance": _inst,
                        "method": _trainer_config,
                        "depth": _depth,
                        "evaluation": _evaluation,
                        "with_aer": _with_aer,
                        "method_label": utils.labels.trainer_config_to_method_label(
                            _trainer_config
                        ),
                        "evaluation_label": utils.labels.trainer_config_to_evaluation_label(
                            _trainer_config
                        ),
                        "graph_type": utils.instance.graph_type(_inst),
                    }
                    for _inst in _instances
                ]
            )
df_missing = pd.DataFrame.from_records(missing_records)
if len(df_missing) == 0:
    display(
        f"No missing instances for problem_class={table.problem_class} at P={missing_depth}"
    )
else:
    display(df_missing)
# Out:
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2204: UserWarning: Method 'F_MPSAer.json' for evaluation 'MPS' (with Aer) has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2204: UserWarning: Method 'LR_MPSAer_angle_opt.json' for evaluation 'MPS' (with Aer) has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2204: UserWarning: Method 'RTS_MPSAer.json' for evaluation 'MPS' (with Aer) has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2204: UserWarning: Method 'F_MPS.json' for evaluation 'MPS' (without Aer) has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2204: UserWarning: Method 'LR_MPS_angle_opt.json' for evaluation 'MPS' (without Aer) has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2204: UserWarning: Method 'RTS_MPS.json' for evaluation 'MPS' (without Aer) has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2208: UserWarning: Method 'F_PP.json' for evaluation 'PP' has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2208: UserWarning: Method 'LR_PP_angle_opt.json' for evaluation 'PP' has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2208: UserWarning: Method 'RTS_PP.json' for evaluation 'PP' has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2208: UserWarning: Method 'F_SV.json' for evaluation 'SV' has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2208: UserWarning: Method 'LR_SV_angle_opt.json' for evaluation 'SV' has no data in the database
#   warnings.warn(
# /Users/jju/Desktop/QAOA-Parameter-Setting/qaoa_parameter_setting/utils/database/results_database.py:2208: UserWarning: Method 'TS_SV.json' for evaluation 'SV' has no data in the database
#   warnings.warn(
#                                     instance         method  depth evaluation  \
# 0              002_19nodes_5swap_layers.json     TS_SV.json     10         SV
# 1              001_16nodes_2swap_layers.json     TS_SV.json     10         SV
# 2       000_16nodes_erdosrenyi20percent.json     TS_SV.json     10         SV
# 3              001_17nodes_2swap_layers.json     TS_SV.json     10         SV
# 4            006_16nodes_random9regular.json     TS_SV.json     10         SV
# ...                                      ...            ...    ...        ...
# 2482         001_40nodes_random3regular.json  F_MPSAer.json     10        MPS
# 2483  005_4_1_heavyhex_39nodes_weighted.json  F_MPSAer.json     10        MPS
# 2484          001_100nodes_6swap_layers.json  F_MPSAer.json     10        MPS
# 2485  004_4_1_heavyhex_39nodes_weighted.json  F_MPSAer.json     10        MPS
# 2486           004_40nodes_8swap_layers.json  F_MPSAer.json     10        MPS
#
#      with_aer method_label evaluation_label      graph_type
# 0        None      TS.json               SV    line_to_full
# 1        None      TS.json               SV    line_to_full
# 2        None      TS.json               SV     erdos_renyi
# 3        None      TS.json               SV    line_to_full
# 4        None      TS.json               SV  random_regular
# ...       ...          ...              ...             ...
# 2482     True    FAer.json        MPS (Aer)  random_regular
# 2483     True    FAer.json        MPS (Aer)       heavy_hex
# 2484     True    FAer.json        MPS (Aer)    line_to_full
# 2485     True    FAer.json        MPS (Aer)       heavy_hex
# 2486     True    FAer.json        MPS (Aer)    line_to_full
#
# [2487 rows x 8 columns]

# %%
# Save missing instances to CSV.
if len(df_missing) > 0:
    df_missing[["instance", "method", "depth"]].sort_values(
        ["instance", "method", "depth"]
    ).to_csv(f"summary_missing_{table.problem_class}.csv")
else:
    display(
        f"No missing instances for problem_class={table.problem_class} at P={missing_depth}"
    )
    display("Emptying CSV file.")
    with open(f"summary_missing_{table.problem_class}.csv", "w") as f:
        # Write just the header
        f.write(",instance,method,depth\n")

# %% [markdown]
# ### Pivot Table of Missing Instances

# %%
if len(df_missing) > 0:
    pivot_missing = df_missing.pivot_table(
        values="instance",
        index=["evaluation_label", "method_label"],
        columns=["graph_type"],
        aggfunc="count",
    )
    pivot_missing = pivot_missing.reindex(index=row_index)
    display(
        f"Missing Runs for problem_class={table.problem_class} at P={missing_depth}"
    )
    display(
        pivot_missing.style.format(precision=0, na_rep=" ")
        .background_gradient("RdYlGn_r")  # pyright: ignore[reportAttributeAccessIssue]
        .highlight_null("transparent")
    )
else:
    print("No missing configurations.")
# Out:
# 'Missing Runs for problem_class=MC at P=10'
# <style type="text/css">
# #T_f3135_row0_col0, #T_f3135_row0_col1, #T_f3135_row0_col2, #T_f3135_row0_col3, #T_f3135_row2_col0, #T_f3135_row2_col1, #T_f3135_row2_col2, #T_f3135_row2_col3, #T_f3135_row3_col0, #T_f3135_row3_col1, #T_f3135_row3_col2, #T_f3135_row3_col3, #T_f3135_row4_col0, #T_f3135_row4_col1, #T_f3135_row4_col2, #T_f3135_row4_col3, #T_f3135_row6_col0, #T_f3135_row6_col1, #T_f3135_row6_col2, #T_f3135_row6_col3, #T_f3135_row7_col0, #T_f3135_row7_col1, #T_f3135_row7_col2, #T_f3135_row7_col3, #T_f3135_row8_col0, #T_f3135_row8_col1, #T_f3135_row8_col2, #T_f3135_row8_col3, #T_f3135_row9_col0, #T_f3135_row9_col1, #T_f3135_row9_col2, #T_f3135_row9_col3, #T_f3135_row11_col0, #T_f3135_row11_col1, #T_f3135_row11_col2, #T_f3135_row11_col3, #T_f3135_row12_col0, #T_f3135_row12_col1, #T_f3135_row12_col2, #T_f3135_row12_col3, #T_f3135_row13_col0, #T_f3135_row13_col1, #T_f3135_row13_col2, #T_f3135_row13_col3, #T_f3135_row15_col0, #T_f3135_row15_col1, #T_f3135_row15_col2, #T_f3135_row15_col3, #T_f3135_row16_col0, #T_f3135_row16_col1, #T_f3135_row16_col2, #T_f3135_row16_col3, #T_f3135_row17_col0, #T_f3135_row17_col1, #T_f3135_row17_col2, #T_f3135_row17_col3, #T_f3135_row18_col0, #T_f3135_row18_col1, #T_f3135_row18_col2, #T_f3135_row18_col3, #T_f3135_row19_col0, #T_f3135_row19_col1, #T_f3135_row19_col2, #T_f3135_row19_col3, #T_f3135_row21_col0, #T_f3135_row21_col1, #T_f3135_row21_col2, #T_f3135_row21_col3, #T_f3135_row22_col0, #T_f3135_row22_col1, #T_f3135_row22_col2, #T_f3135_row22_col3, #T_f3135_row24_col0, #T_f3135_row24_col1, #T_f3135_row24_col2, #T_f3135_row24_col3, #T_f3135_row25_col0, #T_f3135_row25_col1, #T_f3135_row25_col2, #T_f3135_row25_col3, #T_f3135_row26_col0, #T_f3135_row26_col1, #T_f3135_row26_col2, #T_f3135_row26_col3, #T_f3135_row27_col0, #T_f3135_row27_col1, #T_f3135_row27_col2, #T_f3135_row27_col3, #T_f3135_row29_col0, #T_f3135_row29_col1, #T_f3135_row29_col2, #T_f3135_row29_col3, #T_f3135_row30_col0, #T_f3135_row30_col1, #T_f3135_row30_col2, #T_f3135_row30_col3, #T_f3135_row31_col0, #T_f3135_row31_col1, #T_f3135_row31_col2, #T_f3135_row31_col3, #T_f3135_row32_col0, #T_f3135_row32_col1, #T_f3135_row32_col2, #T_f3135_row32_col3, #T_f3135_row33_col0, #T_f3135_row33_col1, #T_f3135_row33_col2, #T_f3135_row33_col3, #T_f3135_row35_col0, #T_f3135_row35_col1, #T_f3135_row35_col2, #T_f3135_row35_col3, #T_f3135_row36_col0, #T_f3135_row36_col1, #T_f3135_row36_col2, #T_f3135_row36_col3, #T_f3135_row38_col0, #T_f3135_row38_col1, #T_f3135_row38_col2, #T_f3135_row38_col3, #T_f3135_row39_col0, #T_f3135_row39_col1, #T_f3135_row39_col2, #T_f3135_row39_col3, #T_f3135_row40_col0, #T_f3135_row40_col1, #T_f3135_row40_col2, #T_f3135_row40_col3, #T_f3135_row41_col0, #T_f3135_row41_col1, #T_f3135_row41_col2, #T_f3135_row41_col3, #T_f3135_row43_col0, #T_f3135_row43_col1, #T_f3135_row43_col2, #T_f3135_row43_col3, #T_f3135_row44_col0, #T_f3135_row44_col1, #T_f3135_row44_col2, #T_f3135_row44_col3, #T_f3135_row45_col0, #T_f3135_row45_col1, #T_f3135_row45_col2, #T_f3135_row45_col3, #T_f3135_row46_col0, #T_f3135_row46_col1, #T_f3135_row46_col2, #T_f3135_row46_col3, #T_f3135_row47_col0, #T_f3135_row47_col1, #T_f3135_row47_col2, #T_f3135_row47_col3, #T_f3135_row49_col0, #T_f3135_row49_col1, #T_f3135_row49_col2, #T_f3135_row49_col3, #T_f3135_row50_col0, #T_f3135_row50_col1, #T_f3135_row50_col2, #T_f3135_row50_col3, #T_f3135_row51_col0, #T_f3135_row51_col1, #T_f3135_row51_col2, #T_f3135_row51_col3, #T_f3135_row52_col0, #T_f3135_row52_col1, #T_f3135_row52_col2, #T_f3135_row52_col3, #T_f3135_row53_col0, #T_f3135_row53_col1, #T_f3135_row53_col2, #T_f3135_row53_col3, #T_f3135_row54_col0, #T_f3135_row54_col1, #T_f3135_row54_col2, #T_f3135_row54_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
#   background-color: transparent;
# }
# #T_f3135_row1_col0, #T_f3135_row1_col1, #T_f3135_row1_col3, #T_f3135_row5_col0, #T_f3135_row5_col1, #T_f3135_row5_col3, #T_f3135_row10_col0, #T_f3135_row10_col1, #T_f3135_row10_col3, #T_f3135_row14_col0, #T_f3135_row14_col2, #T_f3135_row20_col0, #T_f3135_row20_col2, #T_f3135_row23_col0, #T_f3135_row23_col2, #T_f3135_row28_col0, #T_f3135_row34_col0, #T_f3135_row37_col0, #T_f3135_row42_col1, #T_f3135_row48_col1, #T_f3135_row55_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f3135_row1_col2, #T_f3135_row5_col2, #T_f3135_row10_col2 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_f3135_row14_col1, #T_f3135_row20_col1, #T_f3135_row23_col1, #T_f3135_row42_col0, #T_f3135_row42_col2, #T_f3135_row42_col3, #T_f3135_row48_col0, #T_f3135_row48_col2, #T_f3135_row48_col3, #T_f3135_row55_col0, #T_f3135_row55_col2, #T_f3135_row55_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f3135_row14_col3, #T_f3135_row20_col3, #T_f3135_row23_col3 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_f3135_row28_col1, #T_f3135_row34_col1, #T_f3135_row37_col1 {
#   background-color: #d22b27;
#   color: #f1f1f1;
# }
# #T_f3135_row28_col2, #T_f3135_row34_col2, #T_f3135_row37_col2 {
#   background-color: #fee18d;
#   color: #000000;
# }
# #T_f3135_row28_col3, #T_f3135_row34_col3, #T_f3135_row37_col3 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f3135">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >graph_type</th>
#       <th id="T_f3135_level0_col0" class="col_heading level0 col0" >erdos_renyi</th>
#       <th id="T_f3135_level0_col1" class="col_heading level0 col1" >heavy_hex</th>
#       <th id="T_f3135_level0_col2" class="col_heading level0 col2" >line_to_full</th>
#       <th id="T_f3135_level0_col3" class="col_heading level0 col3" >random_regular</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3135_level0_row0" class="row_heading level0 row0" rowspan="14">MPS (Aer)</th>
#       <th id="T_f3135_level1_row0" class="row_heading level1 row0" >F.json</th>
#       <td id="T_f3135_row0_col0" class="data row0 col0" > </td>
#       <td id="T_f3135_row0_col1" class="data row0 col1" > </td>
#       <td id="T_f3135_row0_col2" class="data row0 col2" > </td>
#       <td id="T_f3135_row0_col3" class="data row0 col3" > </td>
#     </tr>
#     <tr>
#       <th id="T_f3135_level1_row1" class="row_heading level1 row1" >FAer.json</th>
#       <td id="T_f3135_row1_col0" class="data row1 col0" >20</td>
#       <td id="T_f3135_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_f3135_row1_col2" class="data row1 col2" >50</td>
#       <td id="T_f3135_row1_col3" class="data row1 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_f3135_level1_row2" class="row_heading level1 row2" >Fixed Angles*</th>
#       <td id="T_f3135_row2_col0" class="data row2 col0" > </td>
#       <td id="T_f3135_row2_col1" class="data row2 col1" > </td>
#       <td id="T_f3135_row2_col2" class="data row2 col2" > </td>
#       <td id="T_f3135_row2_col3" class="data row2 col3" > </td>
#     </tr>
#     <tr>
#       <th id="T_f3135_level1_row3" class="row_heading level1 row3" >Fixed Angles†</th>
#       <td id="T_f3135_row3_col0" class="data row3 col0" > </td>
#       <td id="T_f3135_row3_col1" class="data row3 col1" > </td>
#       <td id="T_f3135_row3_col2" class="data row3 col2" > </td>
#       <td id="T_f3135_row3_col3" class="data row3 col3" > </td>
#     </tr>
#     <tr>
#       <th id="T_f3135_level1_row4" class="row_heading level1 row4" >Interp.*</th>
#       <td id="T_f3135_row4_col0" class="data row4 col0" > </td>
#       <td id="T_f3135_row4_col1" class="data row4 col1" > </td>
#       <td id="T_f3135_row4_col2" class="data row4 col2" > </td>
#       <td id="T_f3135_row4_col3" class="data row4 col3" > </td>
#     </tr>
#     <tr>
#       <th id="T_f3135_level1_row5" class="row_heading level1 row5" >LRAer_angle_opt.json</th>
#       <td id="T_f3135_row5_col0" class="data row5 col0" >20</td>
#       <td id="T_f3135_row5_col1" class="data row5 col1" >20</td>
#       <td id="T_f3135_row5_col2" class="data row5 col2" >50</td>
#       <td id="T_f3135_row5_col3" class="data row5 col3" >11</td>
#     </tr>
#     <tr>
#       <th id="T_f3135_level1_row6" class="row_heading level1 row6" >LR_angle_opt.json</th>
